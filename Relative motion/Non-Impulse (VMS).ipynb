# %% [markdown]
# The aim of this script is to simulate the motion a chaser satellite in close proximity to a target satellite. This uses the Clohessy Wiltshire equations to draw the chaser satellite in the reference frame of the target satellite. This particular sumulation attempts to simulate the motion of the satellite given inital condistions and then provides the means to apply an extended burn at a across a chosen time period and fuel capacity.
#
#
# This script works on making the fuel compoent of the siluation more accurate.

# %%
import numpy as np
import plotly.graph_objects as go
import math

# Gravitational parameter (mu) and mean motion (n)
mu = 398600.4418  # km^3/s^2 (gravitational parameter of Earth)
sma = 7000  # km (semi-major axis of the target's orbit)
n = np.sqrt(mu / sma**3)  # mean motion of the target

# Initial conditions in the target's orbit reference frame
r0_chaser = np.array([10.0, 9.0, -30.0])  # Initial relative position of chaser, km
v0_chaser = np.array([3, 5, 0.1])  # Initial relative velocity of chaser, km/s

# Thrust parameters
thrust_start_time = 2000  # Time delay before thrust starts in seconds
thrust_duration = 6000    # Thrust duration in seconds
thrust_force = np.array([0, 100000, 0])  # Thrust force in N
specific_impulse = 3000  # Specific impulse of the propulsion system, seconds
fuel_mass_inital = 1000  # Initial mass of the fuel
spacecraft_mass = 4000 # Initial dry mass of the craft, kg
total_mass_initial = spacecraft_mass + fuel_mass_inital  # Initial total mass of the spacecraft

# Time parameters
t_final = 10000  # Total simulation time, seconds
dt = 1  # Time step, seconds

# Time array
t = np.arange(0, t_final, dt)

# Position and velocity arrays
r_chaser = np.zeros((len(t), 3))
v_chaser = np.zeros((len(t), 3))

# Set initial conditions
r_chaser[0] = r0_chaser
v_chaser[0] = v0_chaser

# Clohessy-Wiltshire equations for relative motion
def clohessy_wiltshire(r, v, t, n):
    x, y, z = r
    x_dot, y_dot, z_dot = v
    
    x_ddot = 3 * n**2 * x + 2 * n * y_dot
    y_ddot = -2 * n * x_dot
    z_ddot = -n**2 * z
    
    return np.array([x_dot, y_dot, z_dot]), np.array([x_ddot, y_ddot, z_ddot])


# Initialize the flag variable before the loop
fuel_depleted_flag = False

#initialise current mass
current_mass = total_mass_initial

# Simulation loop
for i in range(1, len(t)):
    # Get current state
    r = r_chaser[i-1]
    v = v_chaser[i-1]
    
    # Find accelerations using Clohessy-Wiltshire equations
    v, a = clohessy_wiltshire(r, v, t[i], n)
    thrust_acceleration = np.array([0.0, 0.0, 0.0])
    # Calculate thrust acceleration using rocket equation
    if thrust_start_time <= t[i] <= (thrust_start_time + thrust_duration):
    
        if (current_mass - spacecraft_mass) > 0:
            exhaust_velocity = specific_impulse * 9.81  # Exhaust velocity in m/s
            thrust_acceleration = thrust_force / current_mass  # Thrust acceleration in m/s^2
            thrust_acceleration = thrust_acceleration * 1e-3  # Convert thrust acceleration to km/s^2
            print("Thrust acceleration (km/s^2):", thrust_acceleration)
            current_mass = current_mass*math.exp((-(np.linalg.norm(thrust_acceleration)*dt))/(exhaust_velocity))  # Update mass of the spacecraft
        else:
            if not fuel_depleted_flag:
                fueldepleted = True
                print("fuel depleted at: ", t[i], "seconds")
                fuel_depleted_flag = True
            thrust_acceleration = np.array([0.0, 0.0, 0.0])  # No thrust
    
    # Total acceleration
    total_acceleration = a + thrust_acceleration
    
    # Update position and velocity
    r_chaser[i] = r + v * dt
    v_chaser[i] = v + total_acceleration * dt


print("fuel used: ", (fuel_mass_inital-(current_mass - spacecraft_mass)) , "kg, out of ", fuel_mass_inital, "kg")




# Plotting with Plotly for interactive visualization
r_chaser_scaled = r_chaser / sma

# Create traces for plotting
trace = go.Scatter3d(
    x=r_chaser_scaled[:, 0],
    y=r_chaser_scaled[:, 1],
    z=r_chaser_scaled[:, 2],
    mode='markers',
    name='Chaser Satellite',
    marker=dict(
        color='blue',
        size=2
    )
)

initial_trace = go.Scatter3d(
    x=[r_chaser_scaled[0, 0]],
    y=[r_chaser_scaled[0, 1]],
    z=[r_chaser_scaled[0, 2]],
    mode='markers',
    name='Initial Position',
    marker=dict(
        color='black',
        size=5
    )
)

target_trace = go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    name='Target Satellite',
    marker=dict(
        color='red',
        size=5
    )
)

thrust_start_trace = go.Scatter3d(
    x=[r_chaser_scaled[thrust_start_time, 0]],
    y=[r_chaser_scaled[thrust_start_time, 1]],
    z=[r_chaser_scaled[thrust_start_time, 2]],
    mode='markers',
    name='Thrust Start',
    marker=dict(
        color='green',
        size=5
    )
)

if (current_mass - spacecraft_mass) <= 0:
    thrust_end_trace = go.Scatter3d(
        x=[r_chaser_scaled[fueldepleted, 0]],
        y=[r_chaser_scaled[fueldepleted, 1]],
        z=[r_chaser_scaled[fueldepleted, 2]],
        mode='markers',
        name='Thrust End',
        marker=dict(
            color='yellow',
            size=5
        )
    )
else:
    thrust_end_trace = go.Scatter3d(
        x=[r_chaser_scaled[thrust_start_time+thrust_duration, 0]],
        y=[r_chaser_scaled[thrust_start_time+thrust_duration, 1]],
        z=[r_chaser_scaled[thrust_start_time+thrust_duration, 2]],
        mode='markers',
        name='Thrust End',
        marker=dict(
            color='yellow',
            size=5
        )
    )

# Create the layout
layout = go.Layout(
    title='Relative Motion of the Chaser Satellite',
    scene=dict(
        xaxis=dict(title='X/a [km]'),
        yaxis=dict(title='Y/a [km]'),
        zaxis=dict(title='Z/a [km]')
    )
)

# Create the figure and add the traces
fig = go.Figure(data=[trace, target_trace, thrust_start_trace, thrust_end_trace, initial_trace], layout=layout)

# Show the figure
fig.show()
# Out:
# Thrust acceleration (km/s^2): [0.   0.02 0.  ]
# Thrust acceleration (km/s^2): [0.         0.02000001 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000003 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000004 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000005 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000007 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000008 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200001 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000011 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000012 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000014 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000015 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000016 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000018 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000019 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200002 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000022 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000023 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000024 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000026 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000027 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000029 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200003 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000031 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000033 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000034 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000035 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000037 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000038 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000039 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000041 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000042 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000043 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000045 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000046 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000048 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000049 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200005 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000052 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000053 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000054 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000056 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000057 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000058 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200006 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000061 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000063 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000064 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000065 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000067 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000068 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000069 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000071 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000072 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000073 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000075 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000076 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000077 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000079 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200008 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000082 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000083 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000084 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000086 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000087 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000088 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200009 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000091 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000092 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000094 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000095 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000097 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000098 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000099 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000101 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000102 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000103 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000105 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000106 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000107 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000109 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200011 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000111 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000113 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000114 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000116 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000117 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000118 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200012 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000121 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000122 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000124 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000125 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000126 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000128 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000129 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200013 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000132 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000133 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000135 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000136 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000137 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000139 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200014 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000141 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000143 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000144 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000145 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000147 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000148 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200015 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000151 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000152 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000154 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000155 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000156 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000158 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000159 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200016 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000162 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000163 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000164 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000166 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000167 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000169 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200017 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000171 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000173 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000174 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000175 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000177 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000178 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000179 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000181 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000182 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000184 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000185 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000186 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000188 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000189 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200019 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000192 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000193 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000194 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000196 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000197 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000198 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020002 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000201 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000203 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000204 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000205 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000207 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000208 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000209 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000211 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000212 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000213 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000215 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000216 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000217 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000219 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200022 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000222 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000223 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000224 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000226 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000227 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000228 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200023 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000231 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000232 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000234 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000235 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000237 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000238 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000239 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000241 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000242 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000243 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000245 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000246 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000247 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000249 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200025 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000251 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000253 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000254 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000256 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000257 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000258 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200026 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000261 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000262 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000264 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000265 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000266 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000268 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000269 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000271 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000272 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000273 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000275 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000276 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000277 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000279 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200028 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000281 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000283 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000284 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000285 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000287 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000288 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200029 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000291 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000292 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000294 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000295 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000296 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000298 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000299 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020003 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000302 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000303 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000304 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000306 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000307 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000309 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200031 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000311 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000313 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000314 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000315 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000317 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000318 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000319 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000321 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000322 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000324 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000325 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000326 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000328 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000329 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200033 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000332 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000333 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000334 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000336 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000337 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000338 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200034 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000341 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000343 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000344 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000345 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000347 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000348 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000349 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000351 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000352 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000353 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000355 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000356 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000358 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000359 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200036 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000362 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000363 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000364 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000366 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000367 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000368 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200037 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000371 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000372 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000374 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000375 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000377 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000378 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000379 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000381 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000382 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000383 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000385 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000386 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000387 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000389 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200039 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000392 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000393 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000394 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000396 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000397 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000398 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020004 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000401 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000402 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000404 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000405 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000406 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000408 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000409 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000411 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000412 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000413 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000415 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000416 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000417 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000419 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200042 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000421 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000423 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000424 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000426 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000427 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000428 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200043 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000431 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000432 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000434 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000435 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000436 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000438 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000439 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200044 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000442 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000443 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000445 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000446 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000447 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000449 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200045 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000451 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000453 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000454 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000455 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000457 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000458 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200046 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000461 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000462 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000464 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000465 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000466 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000468 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000469 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200047 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000472 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000473 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000474 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000476 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000477 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000479 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200048 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000481 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000483 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000484 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000485 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000487 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000488 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000489 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000491 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000492 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000493 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000495 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000496 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000498 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000499 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020005 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000502 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000503 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000504 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000506 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000507 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000508 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200051 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000511 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000513 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000514 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000515 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000517 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000518 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000519 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000521 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000522 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000523 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000525 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000526 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000527 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000529 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200053 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000532 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000533 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000534 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000536 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000537 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000538 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200054 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000541 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000542 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000544 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000545 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000547 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000548 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000549 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000551 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000552 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000553 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000555 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000556 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000557 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000559 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200056 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000561 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000563 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000564 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000566 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000567 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000568 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200057 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000571 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000572 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000574 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000575 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000576 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000578 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000579 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000581 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000582 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000583 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000585 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000586 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000587 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000589 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200059 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000591 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000593 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000594 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000595 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000597 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000598 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020006 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000601 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000602 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000604 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000605 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000606 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000608 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000609 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200061 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000612 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000613 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000615 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000616 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000617 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000619 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200062 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000621 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000623 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000624 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000625 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000627 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000628 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000629 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000631 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000632 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000634 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000635 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000636 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000638 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000639 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200064 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000642 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000643 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000644 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000646 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000647 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000649 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200065 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000651 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000653 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000654 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000655 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000657 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000658 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000659 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000661 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000662 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000663 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000665 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000666 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000668 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000669 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200067 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000672 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000673 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000674 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000676 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000677 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000678 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200068 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000681 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000683 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000684 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000685 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000687 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000688 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000689 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000691 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000692 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000693 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000695 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000696 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000697 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000699 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020007 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000702 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000703 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000704 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000706 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000707 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000708 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200071 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000711 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000712 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000714 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000715 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000717 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000718 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000719 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000721 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000722 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000723 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000725 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000726 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000727 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000729 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200073 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000731 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000733 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000734 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000736 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000737 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000738 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200074 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000741 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000742 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000744 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000745 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000746 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000748 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000749 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000751 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000752 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000753 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000755 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000756 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000757 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000759 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200076 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000761 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000763 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000764 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000765 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000767 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000768 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200077 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000771 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000772 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000774 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000775 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000776 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000778 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000779 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200078 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000782 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000783 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000785 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000786 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000787 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000789 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200079 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000791 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000793 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000794 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000795 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000797 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000798 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020008 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000801 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000802 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000804 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000805 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000806 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000808 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000809 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200081 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000812 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000813 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000814 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000816 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000817 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000819 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200082 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000821 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000823 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000824 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000825 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000827 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000828 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000829 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000831 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000832 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000834 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000835 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000836 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000838 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000839 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200084 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000842 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000843 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000844 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000846 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000847 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000848 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200085 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000851 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000853 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000854 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000855 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000857 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000858 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000859 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000861 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000862 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000863 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000865 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000866 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000868 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000869 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200087 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000872 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000873 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000874 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000876 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000877 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000878 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200088 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000881 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000882 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000884 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000885 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000887 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000888 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000889 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000891 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000892 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000893 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000895 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000896 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000897 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000899 0.        ]
# Thrust acceleration (km/s^2): [0.       0.020009 0.      ]
# Thrust acceleration (km/s^2): [0.         0.02000902 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000903 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000904 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000906 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000907 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000908 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200091 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000911 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000912 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000914 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000915 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000916 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000918 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000919 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000921 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000922 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000923 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000925 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000926 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000927 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000929 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200093 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000931 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000933 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000934 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000936 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000937 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000938 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200094 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000941 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000942 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000944 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000945 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000946 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000948 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000949 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000951 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000952 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000953 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000955 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000956 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000957 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000959 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200096 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000961 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000963 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000964 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000965 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000967 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000968 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200097 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000971 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000972 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000974 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000975 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000976 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000978 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000979 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200098 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000982 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000983 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000985 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000986 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000987 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000989 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200099 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02000991 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000993 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000994 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000995 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000997 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000998 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02000999 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001001 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001002 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001004 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001005 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001006 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02001008 0.        ]
# ...
# Thrust acceleration (km/s^2): [0.         0.02007853 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007854 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007855 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007857 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007858 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200786 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007861 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007862 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007864 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007865 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007866 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007868 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007869 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200787 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007872 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007873 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007875 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007876 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007877 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007879 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200788 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007881 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007883 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007884 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007886 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007887 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007888 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200789 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007891 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007892 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007894 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007895 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007896 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007898 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007899 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007901 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007902 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007903 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007905 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007906 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007907 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007909 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200791 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007912 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007913 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007914 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007916 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007917 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007918 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200792 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007921 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007923 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007924 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007925 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007927 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007928 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007929 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007931 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007932 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007933 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007935 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007936 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007938 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007939 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200794 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007942 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007943 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007944 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007946 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007947 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007949 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200795 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007951 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007953 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007954 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007955 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007957 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007958 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200796 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007961 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007962 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007964 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007965 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007966 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007968 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007969 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200797 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007972 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007973 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007975 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007976 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007977 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007979 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200798 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007981 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007983 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007984 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007986 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007987 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007988 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200799 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02007991 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007992 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007994 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007995 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007997 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007998 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02007999 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008001 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008002 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008003 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008005 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008006 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008007 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008009 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200801 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008012 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008013 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008014 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008016 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008017 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008018 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200802 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008021 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008023 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008024 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008025 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008027 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008028 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008029 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008031 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008032 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008033 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008035 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008036 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008038 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008039 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200804 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008042 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008043 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008044 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008046 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008047 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008049 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200805 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008051 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008053 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008054 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008055 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008057 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008058 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200806 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008061 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008062 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008064 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008065 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008066 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008068 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008069 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200807 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008072 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008073 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008075 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008076 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008077 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008079 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200808 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008081 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008083 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008084 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008086 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008087 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008088 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200809 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008091 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008092 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008094 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008095 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008097 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008098 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008099 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008101 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008102 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008103 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008105 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008106 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008107 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008109 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200811 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008112 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008113 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008114 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008116 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008117 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008118 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200812 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008121 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008123 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008124 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008125 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008127 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008128 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008129 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008131 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008132 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008134 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008135 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008136 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008138 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008139 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200814 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008142 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008143 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008144 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008146 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008147 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008149 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200815 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008151 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008153 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008154 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008155 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008157 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008158 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200816 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008161 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008162 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008164 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008165 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008166 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008168 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008169 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008171 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008172 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008173 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008175 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008176 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008177 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008179 0.        ]
# Thrust acceleration (km/s^2): [0.        0.0200818 0.       ]
# Thrust acceleration (km/s^2): [0.         0.02008181 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008183 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008184 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008186 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008187 0.        ]
# Thrust acceleration (km/s^2): [0.         0.02008188 0.        ]
# fuel used:  20.39075078746191 kg, out of  1000 kg
