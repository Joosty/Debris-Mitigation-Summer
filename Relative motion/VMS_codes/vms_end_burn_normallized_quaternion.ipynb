# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define global variables
global h, R, w0, m_dot, z_dot
rho_ini = 1000
L = 1  # m
h = L / 2
z0 = h
R = 0.8 * L  # m
w0 = 0.2

# Initial angular rates
w10 = 0
w20 = w0
w30 = 0.3

# Initial mass properties
mf0 = np.pi * R**2 * L * rho_ini  # kg
I10 = mf0 * (R**2 / 4 + h**2 / 3)  # kg*m^2
I30 = mf0 * R**2 / 2  # kg*m^2
Theta0 = 0
F0 = 0
tb = 100  # s
m_dot = -mf0 / tb
z_dot = m_dot / (2 * rho_ini * np.pi * R**2)

# Quaternion initial conditions (representing no initial rotation)
q0 = [1, 0, 0, 0]  # (w, x, y, z)

# Combine initial conditions
Y0 = [mf0, I10, I30, w10, w20, w30, Theta0, F0, z0] + q0

# Define the differential equations (endburn)
def endburn(t, w):
    m, I1, I3, w1, w2, w3, Theta, F, z, qw, qx, qy, qz = w

    # Mass varying terms
    md = m_dot
    I1d = md * (R**2 / 4 + z**2)
    I3d = md * R**2 / 2

    # Distance of mass center from exit plane
    ze = 2 * h - z

    # Equations of motion for the axisymmetric cylinder undergoing uniform burn
    w1d = (I1 - I3) * w2 * w3 / I1 - (I1d - md * (ze**2 + R**2 / 4)) * w1 / I1
    w2d = -(I1 - I3) * w1 * w3 / I1 - (I1d - md * (ze**2 + R**2 / 4)) * w2 / I1
    w3d = -(I3d - md * R**2 / 2) * w3 / I3
    Thetad = (1 - I3 / I1) * w3
    Fd = -(I1d - md * (ze**2 + R**2 / 4)) / I1
    zd = md / m * z

    # Quaternion derivative
    omega_quat = np.array([0, w1, w2, w3])
    quat = np.array([qw, qx, qy, qz])
    quat_dot = 0.5 * np.array(quat_mult(quat, omega_quat))

    # Normalize quaternion to prevent drift
    quat_norm = np.linalg.norm(quat)
    if quat_norm > 0:
        print("resetting the norm because it is", quat_norm)
        quat /= quat_norm

    wd = [md, I1d, I3d, w1d, w2d, w3d, Thetad, Fd, zd] + quat_dot.tolist()

    return wd

# Function to multiply two quaternions
def quat_mult(q, r):
    """
    Multiply two quaternions q and r.
    """
    w1, x1, y1, z1 = q
    w2, x2, y2, z2 = r
    return [
        w1*w2 - x1*x2 - y1*y2 - z1*z2,
        w1*x2 + x1*w2 + y1*z2 - z1*y2,
        w1*y2 - x1*z2 + y1*w2 + z1*x2,
        w1*z2 + x1*y2 - y1*x2 + z1*w2
    ]

# Time span for the simulation
dt = 0.01
t_eval = np.arange(0, tb, dt)

# Solve the ODEs
sol = solve_ivp(endburn, [0, tb], Y0, t_eval=t_eval, atol=1e-9, rtol=1e-8)

# Check if the integration was successful
if sol.status == 0:
    print("Integration successful.")
else:
    print(f"Integration failed with status {sol.status}: {sol.message}")

# Print the final time to check if it reached the end of the burn time
print(f"Final time: {sol.t[-1]}")

# Extract results
t = sol.t
m = sol.y[0]
I1 = sol.y[1]
I3 = sol.y[2]
omega1 = sol.y[3]
omega2 = sol.y[4]
omega3 = sol.y[5]
Theta = sol.y[6]
F = sol.y[7]
z = sol.y[8]
qw, qx, qy, qz = sol.y[9], sol.y[10], sol.y[11], sol.y[12]

# Compute the quaternion norm and check for violations
quat_norm = np.sqrt(qw**2 + qx**2 + qy**2 + qz**2)
norm_violation_indices = np.where(np.abs(quat_norm - 1) > 1e-6)[0]

if len(norm_violation_indices) > 0:
    print(f"Quaternion constraint violated at time steps: {t[norm_violation_indices]}")
else:
    print("Quaternion constraint satisfied throughout the simulation.")

# Plot the quaternion norm over time
plt.figure(figsize=(10, 6))
plt.plot(t, quat_norm, label='Quaternion Norm')
plt.axhline(y=1.0, color='r', linestyle='--', label='Ideal Norm (1.0)')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Norm')
plt.title('Quaternion Norm vs Time')
plt.ylim([0.99, 1.01])  # Adjust y-limits for better visualization
plt.legend()
plt.show()

# Function to convert quaternion to Euler angles (Z-X-Z sequence)
def quat_to_euler_zxz(q):
    """
    Convert a quaternion to Euler angles (Z-X-Z sequence).
    """
    w, x, y, z = q
    # Compute the Euler angles
    psi = np.arctan2(2*(w*z + x*y), 1 - 2*(y**2 + z**2))
    theta = np.arccos(2*(w*y - z*x))
    phi = np.arctan2(2*(w*z + y*x), 1 - 2*(x**2 + y**2))
    return psi, theta, phi

# Extract Euler angles from quaternions
psi, theta, phi = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
for i in range(len(qw)):
    psi[i], theta[i], phi[i] = quat_to_euler_zxz([qw[i], qx[i], qy[i], qz[i]])

# Plot the results
plt.figure(figsize=(12, 6))

# Plot angular velocities
plt.subplot(4, 1, 1)
plt.plot(sol.t, omega1, label='omega1')
plt.plot(sol.t, omega2, label='omega2')
plt.plot(sol.t, omega3, label='omega3')
plt.xlabel('Time (s)')
plt.ylabel('Angular Velocity (rad/s)')
plt.title('Angular Velocity vs Time')
plt.legend()

# Plot Euler angles
plt.subplot(4, 1, 2)
plt.plot(sol.t, psi, label='psi')
plt.plot(sol.t, theta, label='theta')
plt.plot(sol.t, phi, label='phi')
plt.xlabel('Time (s)')
plt.ylabel('Euler Angles (rad)')
plt.title('Euler Angles vs Time')
plt.legend()

# Plot quaternions
plt.subplot(4, 1, 3)
plt.plot(sol.t, qw, label='qw')
plt.plot(sol.t, qx, label='qx')
plt.plot(sol.t, qy, label='qy')
plt.plot(sol.t, qz, label='qz')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Components')
plt.title('Quaternion Components vs Time')
plt.legend()

# Plot mass and moments of inertia
plt.subplot(4, 1, 4)
plt.plot(sol.t, m, label='mass')
plt.plot(sol.t, I1, label='I1')
plt.plot(sol.t, I3, label='I3')
plt.xlabel('Time (s)')
plt.ylabel('Mass and Inertias')
plt.title('Mass and Moments of Inertia vs Time')
plt.legend()

plt.tight_layout()
plt.show()

# Plot the T-handle's total mechanical energy over time
E = 0.5 * (I1 * omega1**2 + I1 * omega2**2 + I3 * omega3**2)

plt.figure()
plt.plot(sol.t, E, '-b', linewidth=2)
plt.xlabel('Time (s)')
plt.ylabel('Total mechanical energy (J)')
plt.ylim([min(E) * 0.8, max(E) * 1.2])  # Set fixed y-axis limits
plt.title('Total Mechanical Energy vs Time')
plt.show()

# Plot the components of the angular momentum about the mass center and the total angular momentum over time
H1 = I1 * omega1  # kg-m^2/s
H2 = I1 * omega2  # kg-m^2/s
H3 = I3 * omega3  # kg-m^2/s
H = np.sqrt(H1**2 + H2**2 + H3**2)  # kg-m^2/s

plt.figure()
plt.plot(sol.t, H1, label='H \cdot e1')
plt.plot(sol.t, H2, label='H \cdot e2')
plt.plot(sol.t, H3, label='H \cdot e3')
plt.plot(sol.t, H, label='||H||')
plt.xlabel('Time (s)')
plt.ylabel('Angular momentum (kg-m^2/s)')
plt.title('Angular Momentum Components vs Time')
plt.legend()
plt.show()

# Function to convert quaternion to rotation matrix
def quat_to_rot_matrix(q):
    """
    Convert a quaternion q to a rotation matrix.
    """
    w, x, y, z = q
    return np.array([
        [1 - 2*(y**2 + z**2), 2*(x*y - z*w), 2*(x*z + y*w)],
        [2*(x*y + z*w), 1 - 2*(x**2 + z**2), 2*(y*z - x*w)],
        [2*(x*z - y*w), 2*(y*z + x*w), 1 - 2*(x**2 + y**2)]
    ])

def animate_t_handle_quat(qw, qx, qy, qz, dt):
    # Specify dimensions for the T-handle
    LAG = 0.5  # cm
    LBC = 4  # cm
    LAD = 2  # cm

    # Initialize arrays to store the T-handle's orientation and key points
    e1 = np.zeros((3, len(qw)))
    e2 = np.zeros((3, len(qw)))
    e3 = np.zeros((3, len(qw)))
    xA, yA, zA = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xB, yB, zB = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xC, yC, zC = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xD, yD, zD = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))

    # Calculate the orientation of the T-handle over time
    for k in range(len(qw)):
        q = [qw[k], qx[k], qy[k], qz[k]]
        R = quat_to_rot_matrix(q)
        e1[:, k] = R @ np.array([1, 0, 0])
        e2[:, k] = R @ np.array([0, 1, 0])
        e3[:, k] = R @ np.array([0, 0, 1])
        xA[k] = -LAG * e2[0, k]
        yA[k] = -LAG * e2[1, k]
        zA[k] = -LAG * e2[2, k]
        xB[k] = xA[k] + LBC / 2 * e1[0, k]
        yB[k] = yA[k] + LBC / 2 * e1[1, k]
        zB[k] = zA[k] + LBC / 2 * e1[2, k]
        xC[k] = xA[k] - LBC / 2 * e1[0, k]
        yC[k] = yA[k] - LBC / 2 * e1[1, k]
        zC[k] = zA[k] - LBC / 2 * e1[2, k]
        xD[k] = xA[k] + LAD * e2[0, k]
        yD[k] = yA[k] + LAD * e2[1, k]
        zD[k] = zA[k] + LAD * e2[2, k]

    # Set up the figure window
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlabel('X (cm)')
    ax.set_ylabel('Y (cm)')
    ax.set_zlabel('Z (cm)')
    ax.set_xlim([-LBC, LBC])
    ax.set_ylim([-LBC, LBC])
    ax.set_zlim([-LAD, LAD])
    ax.set_title('T-handle Animation')

    # Draw the T-handle
    AD, = ax.plot([xA[0], xD[0]], [yA[0], yD[0]], [zA[0], zD[0]], 'k-', linewidth=5)
    BC, = ax.plot([xB[0], xC[0]], [yB[0], yC[0]], [zB[0], zC[0]], 'k-', linewidth=5)

    # Animate the T-handle's motion by updating the figure with its current orientation
    def update(k):
        AD.set_data([xA[k], xD[k]], [yA[k], yD[k]])
        AD.set_3d_properties([zA[k], zD[k]])
        BC.set_data([xB[k], xC[k]], [yB[k], yC[k]])
        BC.set_3d_properties([zB[k], zC[k]])
        return AD, BC,

    ani = FuncAnimation(fig, update, frames=len(qw), interval=dt * 1000, blit=True)
    plt.show()

# Example usage
# Assuming `qw`, `qx`, `qy`, `qz` are the quaternion components obtained from the previous solution
animate_t_handle_quat(qw, qx, qy, qz, dt)

# Plot the quaternion norm over time
plt.figure(figsize=(10, 6))
plt.plot(t, quat_norm, label='Quaternion Norm')
plt.axhline(y=1.0, color='r', linestyle='--', label='Ideal Norm (1.0)')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Norm')
plt.title('Quaternion Norm vs Time')
plt.ylim([0.99, 1.01])  # Adjust y-limits for better visualization
plt.legend()
plt.show()
# Out:
# resetting the norm because it is 1.0
# resetting the norm because it is 1.0000021488109374
# resetting the norm because it is 1.0000000815591934
# resetting the norm because it is 1.0000000000000182
# resetting the norm because it is 0.9999999999986096
# resetting the norm because it is 0.9999999999949541
# resetting the norm because it is 0.999999999994428
# resetting the norm because it is 0.9999999999999999
# resetting the norm because it is 1.0000081558862883
# resetting the norm because it is 1.0000000001823361
# resetting the norm because it is 0.9999999861026555
# resetting the norm because it is 0.999999949565904
# resetting the norm because it is 0.9999999443071365
# resetting the norm because it is 0.9999999999999782
# resetting the norm because it is 1.0001136605745902
# resetting the norm because it is 1.0000000353235492
# resetting the norm because it is 0.9999973042432911
# resetting the norm because it is 0.999990223279687
# resetting the norm because it is 0.9999892083675893
# resetting the norm because it is 0.9999999999420459
# resetting the norm because it is 1.000134476923364
# resetting the norm because it is 1.0000000487662366
# resetting the norm because it is 0.999996231686608
# resetting the norm because it is 0.9999863292993747
# resetting the norm because it is 0.9999849050329757
# resetting the norm because it is 0.9999999998459951
# resetting the norm because it is 1.000151463566659
# resetting the norm because it is 1.0000000610137487
# resetting the norm because it is 0.999995225037248
# resetting the norm because it is 0.9999826717691902
# resetting the norm because it is 0.9999808596772771
# resetting the norm because it is 0.9999999997084753
# resetting the norm because it is 1.0001642763887182
# resetting the norm because it is 1.0000000707449364
# resetting the norm because it is 0.9999943887252554
# resetting the norm because it is 0.999979629487294
# resetting the norm because it is 0.9999774906494435
# resetting the norm because it is 0.9999999995325082
# resetting the norm because it is 1.000172298038956
# resetting the norm because it is 1.0000000766164947
# resetting the norm because it is 0.9999938335704418
# resetting the norm because it is 0.9999776048905594
# resetting the norm because it is 0.9999752429470035
# resetting the norm because it is 0.9999999993287163
# resetting the norm because it is 1.0001763026416512
# resetting the norm because it is 1.0000000788603818
# resetting the norm because it is 0.9999935505337842
# resetting the norm because it is 0.9999765660831871
# resetting the norm because it is 0.9999740824060717
# resetting the norm because it is 0.9999999991094062
# resetting the norm because it is 1.0001780067950445
# resetting the norm because it is 1.0000000789275238
# resetting the norm because it is 0.9999934328332355
# resetting the norm because it is 0.9999761264520395
# resetting the norm because it is 0.9999735829160062
# resetting the norm because it is 0.9999999988825707
# resetting the norm because it is 1.0001788326032368
# resetting the norm because it is 1.0000000781346574
# resetting the norm because it is 0.9999933797695931
# resetting the norm because it is 0.9999759209747704
# resetting the norm because it is 0.9999733416640498
# resetting the norm because it is 0.999999998651386
# resetting the norm because it is 1.0001795074177662
# resetting the norm because it is 1.0000000771620465
# resetting the norm because it is 0.9999933379676549
# resetting the norm because it is 0.9999757560060007
# resetting the norm because it is 0.9999731447726565
# resetting the norm because it is 0.9999999984163456
# resetting the norm because it is 1.0001802498629886
# resetting the norm because it is 1.0000000762102585
# resetting the norm because it is 0.9999932911663248
# resetting the norm because it is 0.9999755724852533
# resetting the norm because it is 0.9999729269396475
# resetting the norm because it is 0.9999999981770996
# resetting the norm because it is 1.0001809859754418
# resetting the norm because it is 1.0000000752107685
# resetting the norm because it is 0.9999932448824452
# resetting the norm because it is 0.9999753904467011
# resetting the norm because it is 0.999972710312616
# resetting the norm because it is 0.9999999979335814
# resetting the norm because it is 1.000181448677509
# resetting the norm because it is 1.0000000739269583
# resetting the norm because it is 0.9999932192861942
# resetting the norm because it is 0.99997528327174
# resetting the norm because it is 0.9999725761606321
# resetting the norm because it is 0.9999999976868077
# resetting the norm because it is 1.0001811835589194
# resetting the norm because it is 1.0000000719716857
# resetting the norm because it is 0.9999932487659001
# resetting the norm because it is 0.9999753762310147
# resetting the norm because it is 0.999972663394447
# resetting the norm because it is 0.9999999974396827
# resetting the norm because it is 1.000179502062942
# resetting the norm because it is 1.0000000687924009
# resetting the norm because it is 0.9999933844242795
# resetting the norm because it is 0.9999758557189556
# resetting the norm because it is 0.9999731789553572
# resetting the norm because it is 0.9999999971979172
# resetting the norm because it is 1.0001754520889725
# resetting the norm because it is 1.0000000637071909
# resetting the norm because it is 0.9999936925728533
# resetting the norm because it is 0.9999769639879108
# resetting the norm because it is 0.9999743922009287
# resetting the norm because it is 0.9999999969707142
# resetting the norm because it is 1.00016779566384
# resetting the norm because it is 1.0000000560140838
# resetting the norm because it is 0.9999942471143608
# resetting the norm because it is 0.9999789716959551
# resetting the norm because it is 0.9999766047596587
# resetting the norm because it is 0.9999999967706441
# resetting the norm because it is 1.000155220426579
# resetting the norm because it is 1.000000045374756
# resetting the norm because it is 0.9999950970099629
# resetting the norm because it is 0.9999820596453819
# resetting the norm because it is 0.999980019629414
# resetting the norm because it is 0.9999999966111504
# resetting the norm because it is 1.0001365347017432
# resetting the norm because it is 1.0000000322080438
# resetting the norm because it is 0.9999962301422848
# resetting the norm because it is 0.9999861870374585
# resetting the norm because it is 0.9999845949601677
# resetting the norm because it is 0.9999999965017999
# resetting the norm because it is 1.0001268833071952
# resetting the norm because it is 1.0000000258399326
# resetting the norm because it is 0.9999967601566727
# resetting the norm because it is 0.9999881160315018
# resetting the norm because it is 0.9999867314702133
# resetting the norm because it is 0.9999999964134917
# resetting the norm because it is 1.0001444466704148
# resetting the norm because it is 1.0000000348344862
# resetting the norm because it is 0.9999957880859922
# resetting the norm because it is 0.9999845526882953
# resetting the norm because it is 0.9999827571630007
# resetting the norm because it is 0.9999999962826976
# resetting the norm because it is 1.0001586879204345
# resetting the norm because it is 1.0000000426503666
# resetting the norm because it is 0.9999949074697699
# resetting the norm because it is 0.9999813221413536
# resetting the norm because it is 0.9999791511230576
# resetting the norm because it is 0.9999999961084668
# resetting the norm because it is 1.000170664428661
# resetting the norm because it is 1.0000000494141723
# resetting the norm because it is 0.9999941034540492
# resetting the norm because it is 0.9999783696463527
# resetting the norm because it is 0.9999758520499729
# resetting the norm because it is 0.9999999958905831
# resetting the norm because it is 1.0001811281297615
# resetting the norm because it is 1.000000055345997
# resetting the norm because it is 0.9999933539156658
# resetting the norm because it is 0.999975614160914
# resetting the norm because it is 0.9999727696494651
# resetting the norm because it is 0.9999999956285951
# resetting the norm because it is 1.0001905246334117
# resetting the norm because it is 1.000000060600079
# resetting the norm because it is 0.999992643639472
# resetting the norm because it is 0.9999729999968182
# resetting the norm because it is 0.9999698419198305
# resetting the norm because it is 0.9999999953217629
# resetting the norm because it is 1.0001989386737509
# resetting the norm because it is 1.0000000651235172
# resetting the norm because it is 0.9999919782431534
# resetting the norm because it is 0.9999705476880274
# resetting the norm because it is 0.9999670917224008
# resetting the norm because it is 0.9999999949701109
# resetting the norm because it is 1.0002056357714135
# resetting the norm because it is 1.0000000682089458
# resetting the norm because it is 0.9999914308490665
# resetting the norm because it is 0.9999685247932187
# resetting the norm because it is 0.9999648170455246
# resetting the norm because it is 0.9999999945789544
# resetting the norm because it is 1.0002073425383597
# resetting the norm because it is 1.0000000670272973
# resetting the norm because it is 0.9999912995039849
# resetting the norm because it is 0.99996802248653
# resetting the norm because it is 0.9999642337943
# resetting the norm because it is 0.9999999941748784
# resetting the norm because it is 1.0002010726371997
# resetting the norm because it is 1.0000000593734746
# resetting the norm because it is 0.9999918446962496
# resetting the norm because it is 0.9999699971379786
# resetting the norm because it is 0.9999664105448299
# resetting the norm because it is 0.9999999938033174
# resetting the norm because it is 1.000201930671701
# resetting the norm because it is 1.0000000575227004
# resetting the norm because it is 0.9999917882007636
# resetting the norm because it is 0.9999697690667851
# resetting the norm because it is 0.9999661331300411
# resetting the norm because it is 0.999999993424007
# resetting the norm because it is 1.0001975534804426
# resetting the norm because it is 1.0000000517098957
# resetting the norm because it is 0.9999921647768005
# resetting the norm because it is 0.999971128625505
# resetting the norm because it is 0.9999676269031531
# resetting the norm because it is 0.9999999930659151
# resetting the norm because it is 1.0001899137771517
# resetting the norm because it is 1.0000000438990773
# resetting the norm because it is 0.9999927902979109
# resetting the norm because it is 0.9999734036710792
# resetting the norm because it is 0.9999701450295142
# resetting the norm because it is 0.9999999927451525
# resetting the norm because it is 1.000181134131022
# resetting the norm because it is 1.0000000359394947
# resetting the norm because it is 0.999993474874654
# resetting the norm because it is 0.9999758992123684
# resetting the norm because it is 0.99997291335911
# resetting the norm because it is 0.9999999924645911
# resetting the norm because it is 1.00017160393155
# resetting the norm because it is 1.0000000282395787
# resetting the norm because it is 0.999994177894132
# resetting the norm because it is 0.9999784667716336
# resetting the norm because it is 0.9999757666664979
# resetting the norm because it is 0.9999999922241399
# resetting the norm because it is 1.0001611510077888
# resetting the norm because it is 1.0000000208298596
# resetting the norm because it is 0.9999949011394157
# resetting the norm because it is 0.9999811134464478
# resetting the norm because it is 0.9999787134376169
# resetting the norm because it is 0.999999992023488
# resetting the norm because it is 1.0001492448358427
# resetting the norm because it is 1.0000000136265152
# resetting the norm because it is 0.9999956639841151
# resetting the norm because it is 0.9999839113780744
# resetting the norm because it is 0.9999818352868126
# resetting the norm because it is 0.9999999918629462
# resetting the norm because it is 1.000134843640568
# resetting the norm because it is 1.000000006508377
# resetting the norm because it is 0.999996500419265
# resetting the norm because it is 0.9999869874349765
# resetting the norm because it is 0.9999852760394192
# resetting the norm because it is 0.9999999917437349
# resetting the norm because it is 1.0001159125114496
# resetting the norm because it is 0.9999999994261278
# resetting the norm because it is 0.999997458224297
# resetting the norm because it is 0.9999905213699019
# resetting the norm because it is 0.9999892408889474
# resetting the norm because it is 0.9999999916675575
# resetting the norm because it is 1.0001278005080938
# resetting the norm because it is 1.0000000020257163
# resetting the norm because it is 0.999996889634957
# resetting the norm because it is 0.999988407668502
# resetting the norm because it is 0.999986852654508
# resetting the norm because it is 0.9999999915647872
# resetting the norm because it is 1.00013938801209
# resetting the norm because it is 1.000000004806963
# resetting the norm because it is 0.9999962796961279
# resetting the norm because it is 0.9999861407291125
# resetting the norm because it is 0.9999842915705914
# resetting the norm because it is 0.999999991430519
# resetting the norm because it is 1.0001460466182657
# resetting the norm because it is 1.0000000059546237
# resetting the norm because it is 0.9999959090410117
# resetting the norm because it is 0.9999847582343916
# resetting the norm because it is 0.9999827243783029
# resetting the norm because it is 0.9999999912749589
# resetting the norm because it is 1.0001491748370916
# resetting the norm because it is 1.0000000057522676
# resetting the norm because it is 0.9999957351530311
# resetting the norm because it is 0.9999841027560646
# resetting the norm because it is 0.9999819739625533
# resetting the norm because it is 0.9999999911079724
# resetting the norm because it is 1.0001501516624065
# resetting the norm because it is 1.000000004703542
# resetting the norm because it is 0.9999956885338555
# resetting the norm because it is 0.9999839177342856
# resetting the norm because it is 0.9999817523467653
# resetting the norm because it is 0.9999999909364318
# resetting the norm because it is 1.0001500572450641
# resetting the norm because it is 1.0000000032526821
# resetting the norm because it is 0.999995706518965
# resetting the norm because it is 0.9999839718043216
# resetting the norm because it is 0.9999817997698613
# resetting the norm because it is 0.9999999907639568
# resetting the norm because it is 1.0001496658233446
# resetting the norm because it is 1.000000001709232
# resetting the norm because it is 0.9999957423906664
# resetting the norm because it is 0.9999840922702415
# resetting the norm because it is 0.9999819221125268
# resetting the norm because it is 0.9999999905915717
# resetting the norm because it is 1.0001495329033123
# resetting the norm because it is 1.0000000002690568
# resetting the norm because it is 0.9999957627683755
# resetting the norm because it is 0.999984155478513
# resetting the norm because it is 0.9999819801066276
# resetting the norm because it is 0.9999999904183793
# resetting the norm because it is 1.0001500818933138
# resetting the norm because it is 0.999999999055509
# resetting the norm because it is 0.9999957424474167
# resetting the norm because it is 0.9999840678118618
# resetting the norm because it is 0.9999818680480504
# resetting the norm because it is 0.9999999902419695
# resetting the norm because it is 1.0001516426440578
# resetting the norm because it is 0.9999999981479576
# resetting the norm because it is 0.9999956612341189
# resetting the norm because it is 0.9999837540755137
# resetting the norm because it is 0.9999815008294728
# resetting the norm because it is 0.9999999900586193
# resetting the norm because it is 1.0001543842944398
# resetting the norm because it is 0.9999999975766736
# resetting the norm because it is 0.9999955070110035
# resetting the norm because it is 0.9999831689953985
# resetting the norm because it is 0.9999808270379147
# resetting the norm because it is 0.9999999898636368
# resetting the norm because it is 1.000158004262216
# resetting the norm because it is 0.9999999972369998
# resetting the norm because it is 0.9999952950772184
# resetting the norm because it is 0.9999823691528752
# resetting the norm because it is 0.9999799102810514
# resetting the norm because it is 0.9999999896529401
# resetting the norm because it is 1.0001617997158925
# resetting the norm because it is 0.9999999969070185
# resetting the norm because it is 0.9999950671097423
# resetting the norm because it is 0.9999815092267694
# resetting the norm because it is 0.9999789250638917
# resetting the norm because it is 0.9999999894248419
# resetting the norm because it is 1.0001623764437015
# resetting the norm because it is 0.9999999955222167
# resetting the norm because it is 0.999995044443055
# resetting the norm because it is 0.9999814115504962
# resetting the norm because it is 0.999978800176183
# resetting the norm because it is 0.9999999891924841
# resetting the norm because it is 1.000156021285642
# resetting the norm because it is 0.9999999921736391
# resetting the norm because it is 0.9999954609334759
# resetting the norm because it is 0.999982947219247
# resetting the norm because it is 0.9999805218350817
# resetting the norm because it is 0.9999999889849615
# resetting the norm because it is 1.0001442588525287
# resetting the norm because it is 0.9999999879930686
# resetting the norm because it is 0.9999961709985512
# resetting the norm because it is 0.9999855799829309
# resetting the norm because it is 0.9999834891399895
# resetting the norm because it is 0.9999999888200353
# resetting the norm because it is 1.00013105446242
# resetting the norm because it is 0.999999984469726
# resetting the norm because it is 0.9999968922434305
# resetting the norm because it is 0.9999882619451542
# resetting the norm because it is 0.9999865198794626
# resetting the norm because it is 0.9999999886958352
# resetting the norm because it is 1.0001193426671173
# resetting the norm because it is 0.9999999820872061
# resetting the norm because it is 0.9999974676265504
# resetting the norm because it is 0.9999904064476597
# resetting the norm because it is 0.9999889482334636
# resetting the norm because it is 0.9999999886016839
# resetting the norm because it is 1.0001032784127641
# resetting the norm because it is 0.9999999802617173
# resetting the norm because it is 0.9999981547174516
# resetting the norm because it is 0.999992978248419
# resetting the norm because it is 0.9999918716754519
# resetting the norm because it is 0.9999999885405483
# resetting the norm because it is 1.00011279305742
# resetting the norm because it is 0.9999999801760684
# resetting the norm because it is 0.9999977734370947
# resetting the norm because it is 0.9999915403723314
# resetting the norm because it is 0.9999902259039348
# resetting the norm because it is 0.9999999884602824
# resetting the norm because it is 1.0001253576324816
# resetting the norm because it is 0.9999999805211154
# resetting the norm because it is 0.9999972110506786
# resetting the norm because it is 0.9999894248330181
# resetting the norm because it is 0.9999878097686216
# resetting the norm because it is 0.9999999883491052
# resetting the norm because it is 1.0001351618477847
# resetting the norm because it is 0.9999999808155722
# resetting the norm because it is 0.9999967295631379
# resetting the norm because it is 0.9999876143567136
# resetting the norm because it is 0.9999857425431871
# resetting the norm because it is 0.999999988208552
# resetting the norm because it is 1.0001426414842147
# resetting the norm because it is 0.9999999809150034
# resetting the norm because it is 0.9999963387695037
# resetting the norm because it is 0.9999861441401827
# resetting the norm because it is 0.99998406281488
# resetting the norm because it is 0.9999999880419872
# resetting the norm because it is 1.000148283363538
# resetting the norm because it is 0.9999999807810169
# resetting the norm because it is 0.9999960322830981
# resetting the norm because it is 0.9999849895582583
# resetting the norm because it is 0.9999827419069015
# resetting the norm because it is 0.9999999878533804
# resetting the norm because it is 1.0001524806094308
# resetting the norm because it is 0.999999980426759
# resetting the norm because it is 0.9999957995498486
# resetting the norm because it is 0.9999841108696824
# resetting the norm because it is 0.9999817344336339
# resetting the norm because it is 0.9999999876467326
# resetting the norm because it is 1.0001554540909516
# resetting the norm because it is 0.9999999798735776
# resetting the norm because it is 0.9999956345115756
# resetting the norm because it is 0.9999834853913283
# resetting the norm because it is 0.9999810146296181
# resetting the norm because it is 0.9999999874261538
# resetting the norm because it is 1.000157271003802
# resetting the norm because it is 0.9999999791365862
# resetting the norm because it is 0.9999955372689106
# resetting the norm because it is 0.9999831135968259
# resetting the norm because it is 0.9999805831613984
# resetting the norm because it is 0.9999999871961631
# resetting the norm because it is 1.000157916923138
# resetting the norm because it is 0.9999999782308832
# resetting the norm because it is 0.9999955109257548
# resetting the norm because it is 0.9999830072842649
# resetting the norm because it is 0.999980453654883
# resetting the norm because it is 0.999999986961818
# resetting the norm because it is 1.000157525000388
# resetting the norm because it is 0.9999999772068734
# resetting the norm because it is 0.9999955478356242
# resetting the norm because it is 0.9999831381254335
# resetting the norm because it is 0.9999805942187336
# resetting the norm because it is 0.9999999867278244
# resetting the norm because it is 1.000156118745113
# resetting the norm because it is 0.9999999761032696
# resetting the norm because it is 0.9999956455938297
# resetting the norm because it is 0.9999834974327771
# resetting the norm because it is 0.999980995311332
# resetting the norm because it is 0.9999999864988147
# resetting the norm because it is 1.0001560360187869
# resetting the norm because it is 0.9999999752694263
# resetting the norm because it is 0.9999956627637898
# resetting the norm because it is 0.9999835558963889
# resetting the norm because it is 0.9999810551295943
# resetting the norm because it is 0.9999999862688985
# resetting the norm because it is 1.0001553999290638
# resetting the norm because it is 0.9999999744276963
# resetting the norm because it is 0.9999957126721126
# resetting the norm because it is 0.9999837376855801
# resetting the norm because it is 0.9999812559897686
# resetting the norm because it is 0.9999999860406253
# resetting the norm because it is 1.000152700033514
# resetting the norm because it is 0.9999999734185319
# resetting the norm because it is 0.9999958832131752
# resetting the norm because it is 0.9999843723325555
# resetting the norm because it is 0.9999819731869176
# resetting the norm because it is 0.9999999858231794
# resetting the norm because it is 1.0001476482227973
# resetting the norm because it is 0.9999999723098638
# resetting the norm because it is 0.9999961825659983
# resetting the norm because it is 0.9999854913568951
# resetting the norm because it is 0.999983243504238
# resetting the norm because it is 0.9999999856260943
# resetting the norm because it is 1.0001399328702405
# resetting the norm because it is 0.9999999712318384
# resetting the norm because it is 0.9999966111283758
# resetting the norm because it is 0.9999870976705292
# resetting the norm because it is 0.9999850717020891
# resetting the norm because it is 0.9999999854581674
# resetting the norm because it is 1.000129256741129
# resetting the norm because it is 0.9999999703962206
# resetting the norm because it is 0.9999971563100304
# resetting the norm because it is 0.999989146172501
# resetting the norm because it is 0.9999874085323515
# resetting the norm because it is 0.9999999853259793
# resetting the norm because it is 1.000115333127505
# resetting the norm because it is 0.9999999701047324
# resetting the norm because it is 0.9999977897828706
# resetting the norm because it is 0.9999915334698467
# resetting the norm because it is 0.9999901390651332
# resetting the norm because it is 0.9999999852324339
# resetting the norm because it is 1.0000982067621647
# resetting the norm because it is 0.9999999707232287
# resetting the norm because it is 0.9999984534297416
# resetting the norm because it is 0.9999940445649762
# resetting the norm because it is 0.9999930213563276
# resetting the norm because it is 0.9999999851750832
# resetting the norm because it is 1.0001126616483504
# resetting the norm because it is 0.9999999699504772
# resetting the norm because it is 0.9999979089646097
# resetting the norm because it is 0.9999919831437941
# resetting the norm because it is 0.9999906534877004
# resetting the norm because it is 0.999999985087622
# resetting the norm because it is 1.0001234689896454
# resetting the norm because it is 0.9999999697597239
# resetting the norm because it is 0.9999974476425647
# resetting the norm because it is 0.9999902423537399
# resetting the norm because it is 0.9999886595466164
# resetting the norm because it is 0.9999999849715955
# resetting the norm because it is 1.0001294114661863
# resetting the norm because it is 0.9999999698013541
# resetting the norm because it is 0.9999971760822209
# resetting the norm because it is 0.9999892202301259
# resetting the norm because it is 0.9999874911610331
# resetting the norm because it is 0.9999999848373243
# resetting the norm because it is 1.000138377480565
# resetting the norm because it is 0.9999999701513519
# resetting the norm because it is 0.9999967371969247
# resetting the norm because it is 0.9999875708667556
# resetting the norm because it is 0.9999856084658374
# resetting the norm because it is 0.9999999846721106
# resetting the norm because it is 1.000144138389815
# resetting the norm because it is 0.9999999705702141
# resetting the norm because it is 0.9999964401500496
# resetting the norm because it is 0.9999864575787022
# resetting the norm because it is 0.999984340488482
# resetting the norm because it is 0.9999999844845585
# resetting the norm because it is 1.0001455939782582
# resetting the norm because it is 0.9999999707920766
# resetting the norm because it is 0.9999963669451052
# resetting the norm because it is 0.9999861864226143
# resetting the norm because it is 0.999984034460431
# resetting the norm because it is 0.9999999842909153
# resetting the norm because it is 1.0001435110731023
# resetting the norm because it is 0.9999999708000483
# resetting the norm because it is 0.9999964833966375
# resetting the norm because it is 0.9999866280912233
# resetting the norm because it is 0.9999845420356797
# resetting the norm because it is 0.9999999841055702
# resetting the norm because it is 1.0001401639793743
# resetting the norm because it is 0.9999999707934538
# resetting the norm because it is 0.9999966627262897
# resetting the norm because it is 0.9999873066106976
# resetting the norm because it is 0.9999853205073282
# resetting the norm because it is 0.999999983933211
# resetting the norm because it is 1.0001396849054973
# resetting the norm because it is 0.9999999710740376
# resetting the norm because it is 0.9999966904159971
# resetting the norm because it is 0.999987416350719
# resetting the norm because it is 0.9999854510011712
# resetting the norm because it is 0.9999999837627348
# resetting the norm because it is 1.0001386866460964
# resetting the norm because it is 0.9999999713806071
# resetting the norm because it is 0.999996743823174
# resetting the norm because it is 0.9999876233396838
# resetting the norm because it is 0.9999856931032076
# resetting the norm because it is 0.9999999835961425
# resetting the norm because it is 1.0001377382375864
# resetting the norm because it is 0.9999999717530306
# resetting the norm because it is 0.9999967935319487
# resetting the norm because it is 0.9999878170693917
# resetting the norm because it is 0.9999859207391117
# resetting the norm because it is 0.999999983433274
# resetting the norm because it is 1.000137019010827
# resetting the norm because it is 0.9999999722036659
# resetting the norm because it is 0.9999968306401957
# resetting the norm because it is 0.999987964106932
# resetting the norm because it is 0.9999860957751058
# resetting the norm because it is 0.9999999832733287
# resetting the norm because it is 1.0001364801884258
# resetting the norm because it is 0.9999999727281853
# resetting the norm because it is 0.9999968578332369
# resetting the norm because it is 0.9999880745398032
# resetting the norm because it is 0.9999862297174787
# resetting the norm because it is 0.9999999831157078
# resetting the norm because it is 1.0001359445760318
# resetting the norm because it is 0.9999999733101015
# resetting the norm because it is 0.9999968840525548
# resetting the norm because it is 0.9999881819130872
# resetting the norm because it is 0.9999863607898365
# resetting the norm because it is 0.9999999829604567
# resetting the norm because it is 1.000135374075378
# resetting the norm because it is 0.9999999739431108
# resetting the norm because it is 0.9999969111823606
# resetting the norm because it is 0.9999882932627164
# resetting the norm because it is 0.9999864969763771
# resetting the norm because it is 0.9999999828077517
# resetting the norm because it is 1.0001342071496395
# resetting the norm because it is 0.9999999745629128
# resetting the norm because it is 0.9999969666392241
# resetting the norm because it is 0.9999885112754022
# resetting the norm because it is 0.9999867551167033
# resetting the norm because it is 0.9999999826596853
# resetting the norm because it is 1.0001316899451695
# resetting the norm because it is 0.9999999750731953
# resetting the norm because it is 0.9999970855976489
# resetting the norm because it is 0.9999889675275926
# resetting the norm because it is 0.9999872847527921
# resetting the norm because it is 0.9999999825206832
# resetting the norm because it is 1.0001267653892647
# resetting the norm because it is 0.9999999753522832
# resetting the norm because it is 0.9999973123944758
# resetting the norm because it is 0.9999898278666156
# resetting the norm because it is 0.9999882743668189
# resetting the norm because it is 0.9999999823977681
# resetting the norm because it is 1.0001177039672553
# resetting the norm because it is 0.9999999752884942
# resetting the norm because it is 0.9999977060570967
# resetting the norm because it is 0.9999913136907554
# resetting the norm because it is 0.9999899761560369
# resetting the norm because it is 0.9999999823005791
# resetting the norm because it is 1.000107360429859
# resetting the norm because it is 0.9999999752647292
# resetting the norm because it is 0.9999981154096637
# resetting the norm because it is 0.999992858962713
# resetting the norm because it is 0.9999917462659142
# resetting the norm because it is 0.9999999822278557
# resetting the norm because it is 1.0001204387658484
# resetting the norm because it is 0.9999999771171603
# resetting the norm because it is 0.9999975811939119
# resetting the norm because it is 0.9999908651876255
# resetting the norm because it is 0.9999894849727916
# resetting the norm because it is 0.9999999821247699
# resetting the norm because it is 1.0001300656058945
# resetting the norm because it is 0.999999979323054
# resetting the norm because it is 0.9999971425278793
# resetting the norm because it is 0.9999892363486418
# resetting the norm because it is 0.9999876459061174
# resetting the norm because it is 0.9999999819949026
# resetting the norm because it is 1.0001393977000983
# resetting the norm because it is 0.9999999820796365
# resetting the norm because it is 0.9999966811357679
# resetting the norm because it is 0.9999875283896738
# resetting the norm because it is 0.999985722800876
# resetting the norm because it is 0.9999999818351771
# resetting the norm because it is 1.0001460550491572
# resetting the norm because it is 0.9999999847994825
# resetting the norm because it is 0.9999963283045314
# resetting the norm because it is 0.9999862299785327
# resetting the norm because it is 0.9999842685732881
# resetting the norm because it is 0.9999999816521534
# resetting the norm because it is 1.0001496766273885
# resetting the norm because it is 0.9999999870956384
# resetting the norm because it is 0.9999961251018582
# resetting the norm because it is 0.9999854915452914
# resetting the norm because it is 0.9999834510007166
# resetting the norm because it is 0.9999999814565023
# resetting the norm because it is 1.0001513226128744
# resetting the norm because it is 0.9999999890185965
# resetting the norm because it is 0.9999960261375056
# resetting the norm because it is 0.9999851422816017
# resetting the norm because it is 0.9999830749576526
# resetting the norm because it is 0.9999999812561094
# resetting the norm because it is 1.000151432680206
# resetting the norm because it is 0.9999999905704898
# resetting the norm because it is 0.9999960109833046
# resetting the norm because it is 0.9999851050535042
# resetting the norm because it is 0.9999830520646787
# resetting the norm because it is 0.9999999810573941
# resetting the norm because it is 1.0001501527293297
# resetting the norm because it is 0.999999991715082
# resetting the norm because it is 0.999996071926158
# resetting the norm because it is 0.9999853502867367
# resetting the norm because it is 0.9999833479812883
# resetting the norm because it is 0.9999999808660133
# resetting the norm because it is 1.000147706434725
# resetting the norm because it is 0.9999999924689124
# resetting the norm because it is 0.9999961949593975
# resetting the norm because it is 0.9999858252741265
# resetting the norm because it is 0.9999839024857261
# resetting the norm because it is 0.9999999806862728
# resetting the norm because it is 1.0001445166082505
# resetting the norm because it is 0.9999999929378467
# resetting the norm because it is 0.9999963546582444
# resetting the norm because it is 0.9999864352545621
# resetting the norm because it is 0.9999846082283179
# resetting the norm because it is 0.9999999805203392
# resetting the norm because it is 1.0001410865272087
# resetting the norm because it is 0.9999999932723751
# resetting the norm because it is 0.9999965226036821
# resetting the norm because it is 0.9999870746893594
# resetting the norm because it is 0.9999853460437417
# resetting the norm because it is 0.9999999803682343
# resetting the norm because it is 1.0001378191068109
# resetting the norm because it is 0.9999999935998767
# resetting the norm because it is 0.9999966777926659
# resetting the norm because it is 0.9999876657720274
# resetting the norm because it is 0.999986028279311
# resetting the norm because it is 0.9999999802285832
# resetting the norm because it is 1.0001350326331147
# resetting the norm because it is 0.9999999940261779
# resetting the norm because it is 0.9999968052996696
# resetting the norm because it is 0.9999881533915748
# resetting the norm because it is 0.9999865930394238
# resetting the norm because it is 0.9999999800991908
# resetting the norm because it is 1.0001326053888968
# resetting the norm because it is 0.9999999945137233
# resetting the norm because it is 0.9999969125903164
# resetting the norm because it is 0.9999885653127977
# resetting the norm because it is 0.9999870717117209
# resetting the norm because it is 0.999999979978472
# resetting the norm because it is 1.0001304918239584
# resetting the norm because it is 0.9999999950506476
# resetting the norm because it is 0.9999970028605099
# resetting the norm because it is 0.9999889134751427
# resetting the norm because it is 0.9999874778483188
# resetting the norm because it is 0.9999999798651364
# resetting the norm because it is 1.0001277504912554
# resetting the norm because it is 0.9999999953055142
# resetting the norm because it is 0.9999971209414026
# resetting the norm because it is 0.9999893633224164
# resetting the norm because it is 0.999987997152044
# resetting the norm because it is 0.9999999797604273
# resetting the norm because it is 1.000124538566587
# resetting the norm because it is 0.999999995325152
# resetting the norm because it is 0.9999972579405864
# resetting the norm because it is 0.9999898818174879
# resetting the norm because it is 0.9999885923078742
# resetting the norm because it is 0.9999999796649429
# resetting the norm because it is 1.0001204331683424
# resetting the norm because it is 0.9999999949580501
# resetting the norm because it is 0.999997430934836
# resetting the norm because it is 0.9999905316930023
# resetting the norm because it is 0.9999893334252801
# resetting the norm because it is 0.9999999795799978
# resetting the norm because it is 1.0001135995723744
# resetting the norm because it is 0.9999999935879521
# resetting the norm because it is 0.999997712626892
# resetting the norm because it is 0.9999915803726898
# resetting the norm because it is 0.9999905197338966
# resetting the norm because it is 0.9999999795099873
# resetting the norm because it is 1.0001161392222515
# resetting the norm because it is 0.9999999954020543
# resetting the norm because it is 0.999997596680479
# resetting the norm because it is 0.9999911641173523
# resetting the norm because it is 0.9999900644645845
# resetting the norm because it is 0.999999979436016
# resetting the norm because it is 1.0001223032079534
# resetting the norm because it is 0.9999999987136489
# resetting the norm because it is 0.9999973175189284
# resetting the norm because it is 0.9999901488617979
# resetting the norm because it is 0.9999889403350826
# resetting the norm because it is 0.9999999793504263
# resetting the norm because it is 1.0001301334759123
# resetting the norm because it is 1.0000000030748928
# resetting the norm because it is 0.999996943081001
# resetting the norm because it is 0.9999887861030593
# resetting the norm because it is 0.9999874303869134
# resetting the norm because it is 0.9999999792482376
# resetting the norm because it is 1.0001367698946568
# resetting the norm because it is 1.0000000073121507
# resetting the norm because it is 0.9999966042288838
# resetting the norm because it is 0.9999875565263995
# resetting the norm because it is 0.999986071795794
# resetting the norm because it is 0.9999999791308353
# resetting the norm because it is 1.0001421622851778
# resetting the norm because it is 1.0000000112430023
# resetting the norm because it is 0.9999963131151217
# resetting the norm because it is 0.9999865038943585
# resetting the norm because it is 0.9999849125718504
# resetting the norm because it is 0.999999979000531
# resetting the norm because it is 1.0001462941489858
# resetting the norm because it is 1.000000014710836
# resetting the norm because it is 0.9999960787771965
# resetting the norm because it is 0.9999856604912974
# resetting the norm because it is 0.9999839878591511
# resetting the norm because it is 0.9999999788603424
# resetting the norm because it is 1.00014878043785
# resetting the norm because it is 1.0000000173603578
# resetting the norm because it is 0.9999959290418695
# resetting the norm because it is 0.9999851272468724
# resetting the norm because it is 0.999983409129245
# resetting the norm because it is 0.9999999787149184
# resetting the norm because it is 1.0001494297784075
# resetting the norm because it is 1.0000000189461151
# resetting the norm because it is 0.9999958798674408
# resetting the norm because it is 0.9999849615268392
# resetting the norm because it is 0.9999832391972377
# resetting the norm because it is 0.9999999785697414
# resetting the norm because it is 1.00014905547802
# resetting the norm because it is 1.0000000198683014
# resetting the norm because it is 0.9999958880011212
# resetting the norm because it is 0.9999850045643711
# resetting the norm because it is 0.9999833007480082
# resetting the norm because it is 0.9999999784277991
# resetting the norm because it is 1.0001484772443234
# resetting the norm because it is 1.0000000205973625
# resetting the norm because it is 0.9999959078731033
# resetting the norm because it is 0.9999850896815531
# resetting the norm because it is 0.9999834082486002
# resetting the norm because it is 0.9999999782895539
# resetting the norm because it is 1.0001480551869366
# resetting the norm because it is 1.0000000213533347
# resetting the norm because it is 0.9999959194569862
# resetting the norm because it is 0.999985143789535
# resetting the norm because it is 0.9999834805105792
# resetting the norm because it is 0.9999999781544228
# resetting the norm because it is 1.0001477502317526
# resetting the norm because it is 1.000000022115908
# resetting the norm because it is 0.9999959249809856
# resetting the norm because it is 0.9999851750736898
# resetting the norm because it is 0.9999835266813623
# resetting the norm because it is 0.999999978021958
# resetting the norm because it is 1.0001472343618438
# resetting the norm because it is 1.0000000226768315
# resetting the norm because it is 0.9999959426761765
# resetting the norm because it is 0.9999852499803498
# resetting the norm because it is 0.9999836204730427
# resetting the norm because it is 0.999999977892612
# resetting the norm because it is 1.000146019283578
# resetting the norm because it is 1.0000000227149919
# resetting the norm because it is 0.9999959994142646
# resetting the norm because it is 0.9999854662746149
# resetting the norm because it is 0.9999838701578249
# resetting the norm because it is 0.9999999777680746
# resetting the norm because it is 1.0001436897426714
# resetting the norm because it is 1.0000000219568952
# resetting the norm because it is 0.9999961169656721
# resetting the norm because it is 0.9999859029973245
# resetting the norm because it is 0.9999843630955597
# resetting the norm because it is 0.9999999776509045
# resetting the norm because it is 1.000140081728844
# resetting the norm because it is 1.0000000203121133
# resetting the norm because it is 0.9999963013142985
# resetting the norm because it is 0.9999865816826401
# resetting the norm because it is 0.9999851228807519
# resetting the norm because it is 0.9999999775436744
# resetting the norm because it is 1.000135078794243
# resetting the norm because it is 1.000000017753973
# resetting the norm because it is 0.9999965533982528
# resetting the norm because it is 0.9999875055525687
# resetting the norm because it is 0.9999861528729216
# resetting the norm because it is 0.9999999774486635
# resetting the norm because it is 1.000128789214673
# resetting the norm because it is 1.000000014431159
# resetting the norm because it is 0.9999968601966721
# resetting the norm because it is 0.999988627143068
# resetting the norm because it is 0.9999874004039573
# resetting the norm because it is 0.9999999773672386
# resetting the norm because it is 1.0001201480079818
# resetting the norm because it is 1.0000000098545612
# resetting the norm because it is 0.9999972612726575
# resetting the norm because it is 0.9999900902585771
# resetting the norm because it is 0.999989024562871
# resetting the norm because it is 0.9999999773018394
# resetting the norm because it is 1.0001261915605777
# resetting the norm because it is 1.0000000137077645
# resetting the norm because it is 0.9999969738202548
# resetting the norm because it is 0.9999890498161934
# resetting the norm because it is 0.9999878779382501
# resetting the norm because it is 0.9999999772265664
# resetting the norm because it is 1.000134869150146
# resetting the norm because it is 1.0000000194393468
# resetting the norm because it is 0.9999965384022921
# resetting the norm because it is 0.9999874723943083
# resetting the norm because it is 0.9999861380571449
# resetting the norm because it is 0.9999999771352335
# resetting the norm because it is 1.0001423266175689
# resetting the norm because it is 1.0000000247498262
# resetting the norm because it is 0.999996139844551
# resetting the norm because it is 0.999986029648354
# resetting the norm because it is 0.9999845478492221
# resetting the norm because it is 0.9999999770285863
# resetting the norm because it is 1.0001491734541597
# resetting the norm because it is 1.0000000299185312
# resetting the norm because it is 0.9999957543194591
# resetting the norm because it is 0.9999846347852682
# resetting the norm because it is 0.9999830111000094
# resetting the norm because it is 0.9999999769065899
# resetting the norm because it is 1.0001553427457772
# resetting the norm because it is 1.0000000348171547
# resetting the norm because it is 0.9999953907535539
# resetting the norm because it is 0.9999833200257532
# resetting the norm because it is 0.99998156322533
# resetting the norm because it is 0.9999999767697066
# resetting the norm because it is 1.0001605618088139
# resetting the norm because it is 1.0000000391535175
# resetting the norm because it is 0.999995070823299
# resetting the norm because it is 0.99998216383212
# resetting the norm because it is 0.9999802907001688
# resetting the norm because it is 0.9999999766195072
# resetting the norm because it is 1.0001646003623283
# resetting the norm because it is 1.000000042650625
# resetting the norm because it is 0.9999948148881977
# resetting the norm because it is 0.9999812398431059
# resetting the norm because it is 0.9999792746285182
# resetting the norm because it is 0.9999999764586669
# resetting the norm because it is 1.0001673580875008
# resetting the norm because it is 1.0000000451389062
# resetting the norm because it is 0.9999946350323642
# resetting the norm because it is 0.9999805916699814
# resetting the norm because it is 0.9999785629474888
# resetting the norm because it is 0.9999999762905766
# resetting the norm because it is 1.0001694500677736
# resetting the norm because it is 1.0000000470700654
# resetting the norm because it is 0.9999944957407587
# resetting the norm because it is 0.9999800903590963
# resetting the norm because it is 0.9999780131286915
# resetting the norm because it is 0.999999976117031
# resetting the norm because it is 1.0001719474591275
# resetting the norm because it is 1.0000000493337309
# resetting the norm because it is 0.9999943285056089
# resetting the norm because it is 0.9999794874722713
# resetting the norm because it is 0.9999773508916768
# resetting the norm because it is 0.9999999759365731
# resetting the norm because it is 1.0001739757695534
# resetting the norm because it is 1.0000000511857734
# resetting the norm because it is 0.9999941904488464
# resetting the norm because it is 0.9999789901236094
# resetting the norm because it is 0.9999768048583684
# resetting the norm because it is 0.9999999757504736
# resetting the norm because it is 1.0001748164067346
# resetting the norm because it is 1.0000000519801509
# resetting the norm because it is 0.9999941308563544
# resetting the norm because it is 0.999978776921096
# resetting the norm because it is 0.9999765720934217
# resetting the norm because it is 0.9999999755624105
# resetting the norm because it is 1.0001736318198482
# resetting the norm because it is 1.0000000509684095
# resetting the norm because it is 0.9999942067396862
# resetting the norm because it is 0.9999790544271145
# resetting the norm because it is 0.9999768804629162
# resetting the norm because it is 0.99999997537879
# resetting the norm because it is 1.0001699758609641
# resetting the norm because it is 1.0000000478045377
# resetting the norm because it is 0.9999944445222634
# resetting the norm because it is 0.9999799183400956
# resetting the norm because it is 0.9999778354978164
# resetting the norm because it is 0.9999999752070451
# resetting the norm because it is 1.000163998946909
# resetting the norm because it is 1.0000000427517963
# resetting the norm because it is 0.9999948244860601
# resetting the norm because it is 0.9999812971880903
# resetting the norm because it is 0.999979358326549
# resetting the norm because it is 0.9999999750531735
# resetting the norm because it is 1.0001559037330445
# resetting the norm because it is 1.000000036184536
# resetting the norm because it is 0.9999953186543205
# resetting the norm because it is 0.9999830896350287
# resetting the norm because it is 0.9999813371892456
# resetting the norm because it is 0.9999999749212451
# resetting the norm because it is 1.0001451171613325
# resetting the norm because it is 1.0000000279485937
# resetting the norm because it is 0.9999959392602563
# resetting the norm because it is 0.9999853401308412
# resetting the norm because it is 0.9999838212275337
# resetting the norm because it is 0.9999999748150075
# resetting the norm because it is 1.0001295150872211
# resetting the norm because it is 1.0000000170905232
# resetting the norm because it is 0.9999967592554997
# resetting the norm because it is 0.9999883132942232
# resetting the norm because it is 0.9999871025847646
# resetting the norm because it is 0.9999999747395545
# resetting the norm because it is 1.0001457585191633
# resetting the norm because it is 1.0000000283471777
# resetting the norm because it is 0.9999959016822517
# resetting the norm because it is 0.9999852054073246
# resetting the norm because it is 0.9999836736720538
# resetting the norm because it is 0.999999974632182
# ...
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025902
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025903
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025907
# resetting the norm because it is 0.9999999675025907
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025905
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# resetting the norm because it is 0.9999999675025906
# Integration failed with status -1: Required step size is less than spacing between numbers.
# Final time: 99.99000000000001
# Quaternion constraint satisfied throughout the simulation.
