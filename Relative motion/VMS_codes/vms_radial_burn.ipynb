# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define the global physical parameters for the variable mass system
rho_ini = 1000
L = 1  # m
h = L / 2  # m
R = 2 * h  # m
w0 = 0.2  # rad/s

# Initial angular rates
w10 = 0  # rad/s
w20 = w0  # rad/s
w30 = 0.3  # rad/s

# Initial mass properties
mf0 = np.pi * R**2 * L * rho_ini  # kg
I10 = mf0 * (R**2 / 4 + h**2 / 3)  # kg*m^2
I30 = mf0 * R**2 / 2  # kg*m^2
Theta0 = 0
F0 = 0
tb = 100  # s
m_dot = -mf0 / tb
rsq0 = 0

# Quaternion initial conditions (representing no initial rotation)
q0 = [1, 0, 0, 0]  # (w, x, y, z)

# Combine initial conditions
Y0 = [mf0, I10, I30, w10, w20, w30, Theta0, F0, rsq0] + q0

# Define the differential equations
def radialburn(t, w):
    m, I1, I3, w1, w2, w3, Theta, F, rsq, qw, qx, qy, qz = w

    # Mass varying terms
    md = m_dot
    rsqd = -md * (R**2 - rsq) / m
    I1d = md * (rsq / 2 + h**2 / 3)  # Transverse moment of inertia
    I3d = md * rsq  # Spin moment of inertia
    ze = h

    # Equations of motion for the axisymmetric cylinder undergoing uniform burn
    w1d = (I1 - I3) * w2 * w3 / I1 - (I1d - md * (ze**2 + R**2 / 4)) * w1 / I1
    w2d = -(I1 - I3) * w1 * w3 / I1 - (I1d - md * (ze**2 + R**2 / 4)) * w2 / I1
    w3d = -(I3d - md * R**2 / 2) * w3 / I3
    Thetad = (1 - I3 / I1) * w3
    Fd = -(I1d - md * (ze**2 + R**2 / 4)) / I1

    # Quaternion derivative
    omega_quat = np.array([0, w1, w2, w3])
    quat = np.array([qw, qx, qy, qz])
    quat_dot = 0.5 * np.array(quat_mult(quat, omega_quat))

    # Normalize quaternion to prevent drift
    quat_norm = np.linalg.norm(quat)
    if quat_norm > 0:
        print("resetting the norm because it is", quat_norm)
        quat /= quat_norm

    wd = [md, I1d, I3d, w1d, w2d, w3d, Thetad, Fd, rsqd, quat_dot[0], quat_dot[1], quat_dot[2], quat_dot[3]]
    return wd

# Function to multiply two quaternions
def quat_mult(q, r):
    w1, x1, y1, z1 = q
    w2, x2, y2, z2 = r
    return [
        w1*w2 - x1*x2 - y1*y2 - z1*z2,
        w1*x2 + x1*w2 + y1*z2 - z1*y2,
        w1*y2 - x1*z2 + y1*w2 + z1*x2,
        w1*z2 + x1*y2 - y1*x2 + z1*w2
    ]

# Time span for the simulation
dt = 0.01
t_eval = np.arange(0, tb, dt)

# Solve the ODEs
sol = solve_ivp(radialburn, [0, tb], Y0, t_eval=t_eval, atol=1e-9, rtol=1e-8)


# Check if the integration was successful
if sol.status == 0:
    print("Integration successful.")
else:
    print(f"Integration failed with status {sol.status}: {sol.message}")

# Print the final time to check if it reached the end of the burn time
print(f"Final time: {sol.t[-1]}")

# Extract results
t = sol.t
mf = sol.y[0]
I1 = sol.y[1]
I3 = sol.y[2]
omega1 = sol.y[3]
omega2 = sol.y[4]
omega3 = sol.y[5]
Theta = sol.y[6]
F = sol.y[7]
rsq = sol.y[8]
qw, qx, qy, qz = sol.y[9], sol.y[10], sol.y[11], sol.y[12]

# Function to convert quaternion to Euler angles (Z-X-Z sequence)
def quat_to_euler_zxz(q):
    w, x, y, z = q
    psi = np.arctan2(2*(w*z + x*y), 1 - 2*(y**2 + z**2))
    theta = np.arccos(2*(w*y - z*x))
    phi = np.arctan2(2*(w*z + y*x), 1 - 2*(x**2 + y**2))
    return psi, theta, phi

# Extract Euler angles from quaternions
psi, theta, phi = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
for i in range(len(qw)):
    psi[i], theta[i], phi[i] = quat_to_euler_zxz([qw[i], qx[i], qy[i], qz[i]])

# Ensure angles are continuous by unwrapping
psi = np.unwrap(psi)
theta = np.unwrap(theta)
phi = np.unwrap(phi)

# Plot the results
plt.figure(figsize=(12, 6))

# Plot angular velocities
plt.subplot(4, 1, 1)
plt.plot(sol.t, omega1, label='omega1')
plt.plot(sol.t, omega2, label='omega2')
plt.plot(sol.t, omega3, label='omega3')
plt.xlabel('Time (s)')
plt.ylabel('Angular Velocity (rad/s)')
plt.title('Angular Velocity vs Time')
plt.legend()

# Plot Euler angles
plt.subplot(4, 1, 2)
plt.plot(sol.t, psi, label='psi')
plt.plot(sol.t, theta, label='theta')
plt.plot(sol.t, phi, label='phi')
plt.xlabel('Time (s)')
plt.ylabel('Euler Angles (rad)')
plt.title('Euler Angles vs Time')
plt.legend()

# Plot quaternions
plt.subplot(4, 1, 3)
plt.plot(sol.t, qw, label='qw')
plt.plot(sol.t, qx, label='qx')
plt.plot(sol.t, qy, label='qy')
plt.plot(sol.t, qz, label='qz')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Components')
plt.title('Quaternion Components vs Time')
plt.legend()

# Plot mass and moments of inertia
plt.subplot(4, 1, 4)
plt.plot(sol.t, mf, label='mass')
plt.plot(sol.t, I1, label='I1')
plt.plot(sol.t, I3, label='I3')
plt.xlabel('Time (s)')
plt.ylabel('Mass and Inertias')
plt.title('Mass and Moments of Inertia vs Time')
plt.legend()

plt.tight_layout()
plt.show()

# Plot the T-handle's total mechanical energy over time
E = 0.5 * (I1 * omega1**2 + I1 * omega2**2 + I3 * omega3**2)

plt.figure()
plt.plot(sol.t, E, '-b', linewidth=2)
plt.xlabel('Time (s)')
plt.ylabel('Total mechanical energy (J)')
plt.ylim([min(E) * 0.8, max(E) * 1.2])
plt.title('Total Mechanical Energy vs Time')
plt.show()

# Plot the components of the angular momentum about the mass center and the total angular momentum over time
H1 = I1 * omega1  # kg-m^2/s
H2 = I1 * omega2  # kg-m^2/s
H3 = I3 * omega3  # kg-m^2/s
H = np.sqrt(H1**2 + H2**2 + H3**2)  # kg-m^2/s

plt.figure()
plt.plot(sol.t, H1, label='H \cdot e1')
plt.plot(sol.t, H2, label='H \cdot e2')
plt.plot(sol.t, H3, label='H \cdot e3')
plt.plot(sol.t, H, label='||H||')
plt.xlabel('Time (s)')
plt.ylabel('Angular momentum (kg-m^2/s)')
plt.title('Angular Momentum Components vs Time')
plt.legend()
plt.show()

# Function to convert quaternion to rotation matrix
def quat_to_rot_matrix(q):
    """
    Convert a quaternion q to a rotation matrix.
    """
    w, x, y, z = q
    return np.array([
        [1 - 2*(y**2 + z**2), 2*(x*y - z*w), 2*(x*z + y*w)],
        [2*(x*y + z*w), 1 - 2*(x**2 + z**2), 2*(y*z - x*w)],
        [2*(x*z - y*w), 2*(y*z + x*w), 1 - 2*(x**2 + y**2)]
    ])

def animate_t_handle_quat(qw, qx, qy, qz, dt):
    # Specify dimensions for the T-handle
    LAG = 0.5  # cm
    LBC = 4  # cm
    LAD = 2  # cm

    # Initialize arrays to store the T-handle's orientation and key points
    e1 = np.zeros((3, len(qw)))
    e2 = np.zeros((3, len(qw)))
    e3 = np.zeros((3, len(qw)))
    xA, yA, zA = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xB, yB, zB = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xC, yC, zC = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))
    xD, yD, zD = np.zeros(len(qw)), np.zeros(len(qw)), np.zeros(len(qw))

    # Calculate the orientation of the T-handle over time
    for k in range(len(qw)):
        q = [qw[k], qx[k], qy[k], qz[k]]
        R = quat_to_rot_matrix(q)
        e1[:, k] = R @ np.array([1, 0, 0])
        e2[:, k] = R @ np.array([0, 1, 0])
        e3[:, k] = R @ np.array([0, 0, 1])
        xA[k] = -LAG * e2[0, k]
        yA[k] = -LAG * e2[1, k]
        zA[k] = -LAG * e2[2, k]
        xB[k] = xA[k] + LBC / 2 * e1[0, k]
        yB[k] = yA[k] + LBC / 2 * e1[1, k]
        zB[k] = zA[k] + LBC / 2 * e1[2, k]
        xC[k] = xA[k] - LBC / 2 * e1[0, k]
        yC[k] = yA[k] - LBC / 2 * e1[1, k]
        zC[k] = zA[k] - LBC / 2 * e1[2, k]
        xD[k] = xA[k] + LAD * e2[0, k]
        yD[k] = yA[k] + LAD * e2[1, k]
        zD[k] = zA[k] + LAD * e2[2, k]

    # Set up the figure window
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.set_xlabel('X (cm)')
    ax.set_ylabel('Y (cm)')
    ax.set_zlabel('Z (cm)')
    ax.set_xlim([-LBC, LBC])
    ax.set_ylim([-LBC, LBC])
    ax.set_zlim([-LAD, LAD])
    ax.set_title('T-handle Animation')

    # Draw the T-handle
    AD, = ax.plot([xA[0], xD[0]], [yA[0], yD[0]], [zA[0], zD[0]], 'k-', linewidth=5)
    BC, = ax.plot([xB[0], xC[0]], [yB[0], yC[0]], [zB[0], zC[0]], 'k-', linewidth=5)

    # Animate the T-handle's motion by updating the figure with its current orientation
    def update(k):
        AD.set_data([xA[k], xD[k]], [yA[k], yD[k]])
        AD.set_3d_properties([zA[k], zD[k]])
        BC.set_data([xB[k], xC[k]], [yB[k], yC[k]])
        BC.set_3d_properties([zB[k], zC[k]])
        return AD, BC,

    ani = FuncAnimation(fig, update, frames=len(qw), interval=dt * 1000, blit=True)
    plt.show()

# Example usage
# Assuming `qw`, `qx`, `qy`, `qz` are the quaternion components obtained from the previous solution
animate_t_handle_quat(qw, qx, qy, qz, dt)

# Plot the quaternion norm over time
quat_norm = np.sqrt(qw**2 + qx**2 + qy**2 + qz**2)
norm_violation_indices = np.where(np.abs(quat_norm - 1) > 1e-6)[0]
if len(norm_violation_indices) > 0:
    print(f"Quaternion constraint violated at time steps: {t[norm_violation_indices]}")
else:
    print("Quaternion constraint satisfied throughout the simulation.")
plt.figure(figsize=(10, 6))
plt.plot(t, quat_norm, label='Quaternion Norm')
plt.axhline(y=1.0, color='r', linestyle='--', label='Ideal Norm (1.0)')
plt.xlabel('Time (s)')
plt.ylabel('Quaternion Norm')
plt.title('Quaternion Norm vs Time')
plt.ylim([0.99, 1.01])  # Adjust y-limits for better visualization
plt.legend()
plt.show()
# Out:
# resetting the norm because it is 1.0
# resetting the norm because it is 1.0000013984746925
# resetting the norm because it is 1.000000076880961
# resetting the norm because it is 0.9999999999979922
# resetting the norm because it is 1.0000000000322506
# resetting the norm because it is 1.0000000000994589
# resetting the norm because it is 1.0000000000913962
# resetting the norm because it is 1.0
# resetting the norm because it is 1.000007686266342
# resetting the norm because it is 0.9999999981567154
# resetting the norm because it is 1.0000000199511772
# resetting the norm because it is 1.000000054844858
# resetting the norm because it is 1.000000042147425
# resetting the norm because it is 0.9999999999999777
# resetting the norm because it is 1.000098442161975
# resetting the norm because it is 0.999999937043021
# resetting the norm because it is 0.9999993009183841
# resetting the norm because it is 0.9999966633825497
# resetting the norm because it is 0.9999954730626814
# resetting the norm because it is 0.9999999999525219
# resetting the norm because it is 1.0001143704843523
# resetting the norm because it is 0.9999999243145101
# resetting the norm because it is 0.9999988995556256
# resetting the norm because it is 0.9999950089235448
# resetting the norm because it is 0.9999934364447393
# resetting the norm because it is 0.9999999998779238
# resetting the norm because it is 1.0001269582831962
# resetting the norm because it is 0.9999999143220355
# resetting the norm because it is 0.9999985145420117
# resetting the norm because it is 0.999993447091227
# resetting the norm because it is 0.9999915369734469
# resetting the norm because it is 0.9999999997756384
# resetting the norm because it is 1.0001352600119495
# resetting the norm because it is 0.9999999079063686
# resetting the norm because it is 0.9999982237768525
# resetting the norm because it is 0.9999922808836813
# resetting the norm because it is 0.9999901309663172
# resetting the norm because it is 0.9999999996516482
# resetting the norm because it is 1.000139870631582
# resetting the norm because it is 0.9999999045573309
# resetting the norm because it is 0.9999980448134841
# resetting the norm because it is 0.9999915706313239
# resetting the norm because it is 0.9999892816587279
# resetting the norm because it is 0.9999999995142093
# resetting the norm because it is 1.0001424915751116
# resetting the norm because it is 0.9999999028597528
# resetting the norm because it is 0.9999979331674689
# resetting the norm because it is 0.9999911327278521
# resetting the norm because it is 0.9999887628476649
# resetting the norm because it is 0.9999999993685451
# resetting the norm because it is 1.0001445465761345
# resetting the norm because it is 0.9999999016530658
# resetting the norm because it is 0.9999978400963131
# resetting the norm because it is 0.9999907704274423
# resetting the norm because it is 0.9999883361983892
# resetting the norm because it is 0.999999999216116
# resetting the norm because it is 1.0001467343345507
# resetting the norm because it is 0.9999999003806163
# resetting the norm because it is 0.999997739187525
# resetting the norm because it is 0.9999903779480354
# resetting the norm because it is 0.9999878743437215
# resetting the norm because it is 0.9999999990562688
# resetting the norm because it is 1.0001492702161612
# resetting the norm because it is 0.9999998988802032
# resetting the norm because it is 0.9999976211353288
# resetting the norm because it is 0.999989918417064
# resetting the norm because it is 0.9999873332600414
# resetting the norm because it is 0.9999999988875734
# resetting the norm because it is 1.0001521336070172
# resetting the norm because it is 0.9999998971781109
# resetting the norm because it is 0.9999974855878709
# resetting the norm because it is 0.9999893908242541
# resetting the norm because it is 0.9999867121047398
# resetting the norm because it is 0.9999999987085366
# resetting the norm because it is 1.00015518085864
# resetting the norm because it is 0.9999998953944504
# resetting the norm because it is 0.9999973375359585
# resetting the norm because it is 0.9999888153429467
# resetting the norm because it is 0.9999860353397224
# resetting the norm because it is 0.9999999985180462
# resetting the norm because it is 1.0001581685230725
# resetting the norm because it is 0.9999998937198773
# resetting the norm because it is 0.9999971871501564
# resetting the norm because it is 0.999988232448028
# resetting the norm because it is 0.9999853514535337
# resetting the norm because it is 0.9999999983158289
# resetting the norm because it is 1.0001607298248536
# resetting the norm because it is 0.9999998924272075
# resetting the norm because it is 0.999997051570965
# resetting the norm because it is 0.9999877097836329
# resetting the norm because it is 0.9999847409465604
# resetting the norm because it is 0.999999998103087
# resetting the norm because it is 1.0001623521486658
# resetting the norm because it is 0.9999998918809737
# resetting the norm because it is 0.999996956403196
# resetting the norm because it is 0.9999873478914072
# resetting the norm because it is 0.9999843229868497
# resetting the norm because it is 0.9999999978832796
# resetting the norm because it is 1.0001623773868422
# resetting the norm because it is 0.9999998925313411
# resetting the norm because it is 0.9999969351352802
# resetting the norm because it is 0.9999872779463312
# resetting the norm because it is 0.9999842527416173
# resetting the norm because it is 0.9999999976628137
# resetting the norm because it is 1.0001599232883853
# resetting the norm because it is 0.9999998949699078
# resetting the norm because it is 0.9999970300824648
# resetting the norm because it is 0.9999876659362633
# resetting the norm because it is 0.9999847267854259
# resetting the norm because it is 0.9999999974516718
# resetting the norm because it is 1.0001541507053773
# resetting the norm because it is 0.9999998997468291
# resetting the norm because it is 0.9999972735332708
# resetting the norm because it is 0.9999886395840617
# resetting the norm because it is 0.9999858973985941
# resetting the norm because it is 0.9999999972621293
# resetting the norm because it is 1.0001444597750095
# resetting the norm because it is 0.9999999072502608
# resetting the norm because it is 0.9999976706613788
# resetting the norm because it is 0.9999902226372698
# resetting the norm because it is 0.999987796019642
# resetting the norm because it is 0.9999999971057899
# resetting the norm because it is 1.0001305876066426
# resetting the norm because it is 0.999999917641048
# resetting the norm because it is 0.9999981905429798
# resetting the norm because it is 0.9999923003052651
# resetting the norm because it is 0.9999902929742012
# resetting the norm because it is 0.9999999969900782
# resetting the norm because it is 1.0001120094002172
# resetting the norm because it is 0.999999931238978
# resetting the norm because it is 0.9999987863467003
# resetting the norm because it is 0.9999946996583661
# resetting the norm because it is 0.9999931938648072
# resetting the norm because it is 0.9999999969169476
# resetting the norm because it is 1.0001177589467325
# resetting the norm because it is 0.999999927626885
# resetting the norm because it is 0.9999986006312552
# resetting the norm because it is 0.999993960164717
# resetting the norm because it is 0.9999923075251579
# resetting the norm because it is 0.9999999968317779
# resetting the norm because it is 1.000131293242934
# resetting the norm because it is 0.9999999187552656
# resetting the norm because it is 0.9999981251450507
# resetting the norm because it is 0.9999920698105441
# resetting the norm because it is 0.9999900447600386
# resetting the norm because it is 0.9999999967134378
# resetting the norm because it is 1.000142061438511
# resetting the norm because it is 0.9999999120566724
# resetting the norm because it is 0.9999976904231941
# resetting the norm because it is 0.9999903579589855
# resetting the norm because it is 0.9999880112126399
# resetting the norm because it is 0.9999999965631505
# resetting the norm because it is 1.0001509655133682
# resetting the norm because it is 0.9999999068674977
# resetting the norm because it is 0.999997290587436
# resetting the norm because it is 0.9999887949893124
# resetting the norm because it is 0.9999861654843261
# resetting the norm because it is 0.9999999963823433
# resetting the norm because it is 1.000158091266806
# resetting the norm because it is 0.9999999030717472
# resetting the norm because it is 0.999996941069058
# resetting the norm because it is 0.9999874377135429
# resetting the norm because it is 0.9999845712692784
# resetting the norm because it is 0.9999999961741838
# resetting the norm because it is 1.0001632587394946
# resetting the norm because it is 0.9999999007099695
# resetting the norm because it is 0.999996666288305
# resetting the norm because it is 0.9999863785383726
# resetting the norm because it is 0.9999833347394107
# resetting the norm because it is 0.999999995944364
# resetting the norm because it is 1.0001649127068053
# resetting the norm because it is 0.9999999006402952
# resetting the norm because it is 0.9999965586225207
# resetting the norm because it is 0.9999859750634574
# resetting the norm because it is 0.9999828747654819
# resetting the norm because it is 0.9999999957069097
# resetting the norm because it is 1.00015944949437
# resetting the norm because it is 0.999999904895433
# resetting the norm because it is 0.9999968061739369
# resetting the norm because it is 0.999986958678636
# resetting the norm because it is 0.9999840511781949
# resetting the norm because it is 0.9999999954917977
# resetting the norm because it is 1.0001698624140107
# resetting the norm because it is 0.9999998997550026
# resetting the norm because it is 0.9999962498658179
# resetting the norm because it is 0.9999848076099264
# resetting the norm because it is 0.9999815337435956
# resetting the norm because it is 0.9999999952310481
# resetting the norm because it is 1.0001744048987897
# resetting the norm because it is 0.999999898295794
# resetting the norm because it is 0.9999959753518735
# resetting the norm because it is 0.9999837602959252
# resetting the norm because it is 0.999980321610734
# resetting the norm because it is 0.999999994948102
# resetting the norm because it is 1.0001722353422666
# resetting the norm because it is 0.9999999006615221
# resetting the norm because it is 0.9999960650374431
# resetting the norm because it is 0.9999841284425551
# resetting the norm because it is 0.9999807728160773
# resetting the norm because it is 0.9999999946749378
# resetting the norm because it is 1.0001660838079107
# resetting the norm because it is 0.9999999051735502
# resetting the norm because it is 0.9999963658654044
# resetting the norm because it is 0.9999853161349268
# resetting the norm because it is 0.9999821860665932
# resetting the norm because it is 0.999999994429466
# resetting the norm because it is 1.0001583585342468
# resetting the norm because it is 0.9999999104759381
# resetting the norm because it is 0.9999967337957365
# resetting the norm because it is 0.9999867652440046
# resetting the norm because it is 0.9999839071253716
# resetting the norm because it is 0.9999999942162363
# resetting the norm because it is 1.00015034946698
# resetting the norm because it is 0.9999999158575685
# resetting the norm because it is 0.9999970956916289
# resetting the norm because it is 0.9999881921564373
# resetting the norm because it is 0.9999856033350282
# resetting the norm because it is 0.9999999940333919
# resetting the norm because it is 1.0001429647133167
# resetting the norm because it is 0.9999999208211325
# resetting the norm because it is 0.9999974090922721
# resetting the norm because it is 0.9999894312911807
# resetting the norm because it is 0.9999870795926892
# resetting the norm because it is 0.9999999938758937
# resetting the norm because it is 1.0001361734568806
# resetting the norm because it is 0.9999999253836289
# resetting the norm because it is 0.9999976801295473
# resetting the norm because it is 0.9999905059901192
# resetting the norm because it is 0.9999883628537115
# resetting the norm because it is 0.9999999937395468
# resetting the norm because it is 1.0001293593027916
# resetting the norm because it is 0.9999999298774646
# resetting the norm because it is 0.999997937293753
# resetting the norm because it is 0.9999915274007855
# resetting the norm because it is 0.9999895841233066
# resetting the norm because it is 0.9999999936224634
# resetting the norm because it is 1.0001221949376922
# resetting the norm because it is 0.9999999344737821
# resetting the norm because it is 0.9999981923862524
# resetting the norm because it is 0.999992541945162
# resetting the norm because it is 0.9999907984844835
# resetting the norm because it is 0.9999999935236208
# resetting the norm because it is 1.0001139936616057
# resetting the norm because it is 0.9999999395291589
# resetting the norm because it is 0.9999984659071616
# resetting the norm because it is 0.9999936309116361
# resetting the norm because it is 0.9999921030118251
# resetting the norm because it is 0.999999993443262
# resetting the norm because it is 1.0001031166960368
# resetting the norm because it is 0.9999999458929663
# resetting the norm because it is 0.9999987978335775
# resetting the norm because it is 0.9999949545354135
# resetting the norm because it is 0.9999936906890073
# resetting the norm because it is 0.9999999933837161
# resetting the norm because it is 1.0001052988762784
# resetting the norm because it is 0.9999999453284057
# resetting the norm because it is 0.9999987200483285
# resetting the norm because it is 0.9999946556939238
# resetting the norm because it is 0.9999933429137258
# resetting the norm because it is 0.9999999933201945
# resetting the norm because it is 1.0001080935692896
# resetting the norm because it is 0.999999944513744
# resetting the norm because it is 0.9999986198103692
# resetting the norm because it is 0.9999942694540784
# resetting the norm because it is 0.999992892325752
# resetting the norm because it is 0.999999993251352
# resetting the norm because it is 1.0001078814365563
# resetting the norm because it is 0.9999999452618938
# resetting the norm because it is 0.9999986134319944
# resetting the norm because it is 0.9999942546405639
# resetting the norm because it is 0.9999928845596193
# resetting the norm because it is 0.9999999931828
# resetting the norm because it is 1.000110962302276
# resetting the norm because it is 0.9999999444262619
# resetting the norm because it is 0.9999984987350249
# resetting the norm because it is 0.9999938137142992
# resetting the norm because it is 0.9999923711972184
# resetting the norm because it is 0.9999999931080659
# resetting the norm because it is 1.0001173246207868
# resetting the norm because it is 0.9999999421545386
# resetting the norm because it is 0.9999982620358223
# resetting the norm because it is 0.9999928968390642
# resetting the norm because it is 0.9999912969406365
# resetting the norm because it is 0.9999999930195407
# resetting the norm because it is 1.000124004376616
# resetting the norm because it is 0.9999999399604438
# resetting the norm because it is 0.9999979936297083
# resetting the norm because it is 0.9999918615043538
# resetting the norm because it is 0.9999900881393018
# resetting the norm because it is 0.9999999929147955
# resetting the norm because it is 1.000131154343363
# resetting the norm because it is 0.9999999378229246
# resetting the norm because it is 0.999997683894669
# resetting the norm because it is 0.9999906712470793
# resetting the norm because it is 0.9999887028567571
# resetting the norm because it is 0.9999999927905969
# resetting the norm because it is 1.0001389218239805
# resetting the norm because it is 0.9999999357444634
# resetting the norm because it is 0.9999973212290867
# resetting the norm because it is 0.9999892824238921
# resetting the norm because it is 0.999987091217421
# resetting the norm because it is 0.9999999926426695
# resetting the norm because it is 1.0001474710836458
# resetting the norm because it is 0.9999999337478692
# resetting the norm because it is 0.9999968906323338
# resetting the norm because it is 0.9999876388321349
# resetting the norm because it is 0.9999851892191314
# resetting the norm because it is 0.9999999924653099
# resetting the norm because it is 1.0001576922988942
# resetting the norm because it is 0.9999999316547287
# resetting the norm because it is 0.9999963348503116
# resetting the norm because it is 0.999985522796488
# resetting the norm because it is 0.9999827458161243
# resetting the norm because it is 0.9999999922479356
# resetting the norm because it is 1.0001674389037667
# resetting the norm because it is 0.999999930320121
# resetting the norm because it is 0.9999957558151884
# resetting the norm because it is 0.9999833282850442
# resetting the norm because it is 0.9999802216955441
# resetting the norm because it is 0.9999999919870866
# resetting the norm because it is 1.0001730500036365
# resetting the norm because it is 0.999999930652878
# resetting the norm because it is 0.9999953839358883
# resetting the norm because it is 0.9999819338411041
# resetting the norm because it is 0.9999786325577251
# resetting the norm because it is 0.9999999916984802
# resetting the norm because it is 1.000168782207873
# resetting the norm because it is 0.9999999336373814
# resetting the norm because it is 0.9999956000531341
# resetting the norm because it is 0.9999827854481848
# resetting the norm because it is 0.9999796440517331
# resetting the norm because it is 0.9999999914302281
# resetting the norm because it is 1.0001573705945852
# resetting the norm because it is 0.9999999382939462
# resetting the norm because it is 0.999996214613228
# resetting the norm because it is 0.9999851573048338
# resetting the norm because it is 0.999982414020371
# resetting the norm because it is 0.9999999912125023
# resetting the norm because it is 1.0001516038719889
# resetting the norm because it is 0.9999999414164914
# resetting the norm because it is 0.9999964916631947
# resetting the norm because it is 0.999986239322566
# resetting the norm because it is 0.9999836900040237
# resetting the norm because it is 0.9999999910175553
# resetting the norm because it is 1.0001502486659375
# resetting the norm because it is 0.9999999433794913
# resetting the norm because it is 0.999996530543599
# resetting the norm because it is 0.99998641032314
# resetting the norm because it is 0.9999839100217095
# resetting the norm because it is 0.9999999908274728
# resetting the norm because it is 1.0001447489596325
# resetting the norm because it is 0.9999999462610448
# resetting the norm because it is 0.9999967828639537
# resetting the norm because it is 0.9999873961335684
# resetting the norm because it is 0.9999850728845477
# resetting the norm because it is 0.9999999906572761
# resetting the norm because it is 1.0001370727867294
# resetting the norm because it is 0.9999999495332658
# resetting the norm because it is 0.9999971313535998
# resetting the norm because it is 0.9999887486616194
# resetting the norm because it is 0.9999866596604591
# resetting the norm because it is 0.9999999905125815
# resetting the norm because it is 1.0001271972123162
# resetting the norm because it is 0.9999999532006743
# resetting the norm because it is 0.9999975583831997
# resetting the norm because it is 0.9999904014957602
# resetting the norm because it is 0.9999885943563331
# resetting the norm because it is 0.9999999903968634
# resetting the norm because it is 1.0001143020897736
# resetting the norm because it is 0.9999999575012756
# resetting the norm because it is 0.9999980710722006
# resetting the norm because it is 0.9999923841850121
# resetting the norm because it is 0.9999909134725508
# resetting the norm because it is 0.9999999903128548
# resetting the norm because it is 1.0001040921202327
# resetting the norm because it is 0.9999999610589569
# resetting the norm because it is 0.9999984304061579
# resetting the norm because it is 0.999993780050973
# resetting the norm because it is 0.9999925522359953
# resetting the norm because it is 0.9999999902493787
# resetting the norm because it is 1.0001193782190458
# resetting the norm because it is 0.9999999585649136
# resetting the norm because it is 0.9999978254817661
# resetting the norm because it is 0.9999914717980988
# resetting the norm because it is 0.9999898827404285
# resetting the norm because it is 0.9999999901533808
# resetting the norm because it is 1.0001315579871461
# resetting the norm because it is 0.99999995766276
# resetting the norm because it is 0.9999972611851523
# resetting the norm because it is 0.9999893351796829
# resetting the norm because it is 0.9999874281142408
# resetting the norm because it is 0.9999999900246005
# resetting the norm because it is 1.0001407535474443
# resetting the norm because it is 0.9999999579908392
# resetting the norm because it is 0.9999967799117272
# resetting the norm because it is 0.9999875259273482
# resetting the norm because it is 0.9999853624973843
# resetting the norm because it is 0.9999999898665524
# resetting the norm because it is 1.0001470680397058
# resetting the norm because it is 0.9999999591973739
# resetting the norm because it is 0.9999964129957402
# resetting the norm because it is 0.9999861581090523
# resetting the norm because it is 0.9999838123936478
# resetting the norm because it is 0.9999999896859216
# resetting the norm because it is 1.0001509464855374
# resetting the norm because it is 0.9999999609498844
# resetting the norm because it is 0.9999961614588366
# resetting the norm because it is 0.9999852317007552
# resetting the norm because it is 0.9999827739119742
# resetting the norm because it is 0.9999999894902827
# resetting the norm because it is 1.0001526754091945
# resetting the norm because it is 0.9999999630064033
# resetting the norm because it is 0.9999960237524408
# resetting the norm because it is 0.9999847380192789
# resetting the norm because it is 0.9999822342741237
# resetting the norm because it is 0.9999999892875276
# resetting the norm because it is 1.0001527786709234
# resetting the norm because it is 0.9999999651888284
# resetting the norm because it is 0.9999959770949884
# resetting the norm because it is 0.9999845890727659
# resetting the norm because it is 0.9999820906666544
# resetting the norm because it is 0.9999999890840725
# resetting the norm because it is 1.0001518190514491
# resetting the norm because it is 0.9999999673938069
# resetting the norm because it is 0.9999959913493535
# resetting the norm because it is 0.9999846700115067
# resetting the norm because it is 0.9999822104087909
# resetting the norm because it is 0.9999999888841667
# resetting the norm because it is 1.0001502547572572
# resetting the norm because it is 0.9999999695733236
# resetting the norm because it is 0.9999960402894897
# resetting the norm because it is 0.999984881380585
# resetting the norm because it is 0.9999824790910983
# resetting the norm because it is 0.9999999886901416
# resetting the norm because it is 1.0001484671044403
# resetting the norm because it is 0.9999999717152938
# resetting the norm because it is 0.9999961017280188
# resetting the norm because it is 0.9999851393737856
# resetting the norm because it is 0.9999828006405223
# resetting the norm because it is 0.9999999885027452
# resetting the norm because it is 1.0001467460292095
# resetting the norm because it is 0.9999999738303598
# resetting the norm because it is 0.9999961589798778
# resetting the norm because it is 0.9999853811978017
# resetting the norm because it is 0.9999831033052319
# resetting the norm because it is 0.9999999883215915
# resetting the norm because it is 1.0001452472639571
# resetting the norm because it is 0.9999999759379661
# resetting the norm because it is 0.999996203289955
# resetting the norm because it is 0.9999855740650782
# resetting the norm because it is 0.9999833497845579
# resetting the norm because it is 0.9999999881457442
# resetting the norm because it is 1.0001439333681046
# resetting the norm because it is 0.9999999780464265
# resetting the norm because it is 0.999996236909151
# resetting the norm because it is 0.9999857265647917
# resetting the norm because it is 0.9999835500122205
# resetting the norm because it is 0.999999987974449
# resetting the norm because it is 1.0001424283470945
# resetting the norm because it is 0.9999999801113606
# resetting the norm because it is 0.9999962811004239
# resetting the norm because it is 0.9999859183793567
# resetting the norm because it is 0.9999837946900909
# resetting the norm because it is 0.9999999878083102
# resetting the norm because it is 1.0001398012895586
# resetting the norm because it is 0.9999999819654907
# resetting the norm because it is 0.9999963876802535
# resetting the norm because it is 0.9999863430108349
# resetting the norm because it is 0.9999843033854017
# resetting the norm because it is 0.9999999876510682
# resetting the norm because it is 1.000134583943091
# resetting the norm because it is 0.99999998329597
# resetting the norm because it is 0.9999966336594303
# resetting the norm because it is 0.9999872873261333
# resetting the norm because it is 0.9999854008574806
# resetting the norm because it is 0.999999987510712
# resetting the norm because it is 1.0001256048090164
# resetting the norm because it is 0.9999999838580864
# resetting the norm because it is 0.9999970637783978
# resetting the norm because it is 0.9999889172983013
# resetting the norm because it is 0.999987274262918
# resetting the norm because it is 0.9999999873966141
# resetting the norm because it is 1.0001130043655773
# resetting the norm because it is 0.9999999837755793
# resetting the norm because it is 0.999997631819301
# resetting the norm because it is 0.9999910600716305
# resetting the norm because it is 0.9999897271372706
# resetting the norm because it is 0.9999999873135704
# resetting the norm because it is 1.0000976255050096
# resetting the norm because it is 0.9999999834158377
# resetting the norm because it is 0.9999982490159629
# resetting the norm because it is 0.9999933850648358
# resetting the norm because it is 0.9999923852669715
# resetting the norm because it is 0.9999999872600877
# resetting the norm because it is 1.0001060894506095
# resetting the norm because it is 0.9999999857768455
# resetting the norm because it is 0.9999978832672576
# resetting the norm because it is 0.999992032435479
# resetting the norm because it is 0.9999908641146728
# resetting the norm because it is 0.999999987191335
# resetting the norm because it is 1.0001180355525092
# resetting the norm because it is 0.9999999895981178
# resetting the norm because it is 0.9999973131508508
# resetting the norm because it is 0.9999899255971502
# resetting the norm because it is 0.9999884963719948
# resetting the norm because it is 0.9999999870964438
# resetting the norm because it is 1.000126955534501
# resetting the norm because it is 0.9999999938109723
# resetting the norm because it is 0.9999968294289878
# resetting the norm because it is 0.9999881494727233
# resetting the norm because it is 0.9999865119666288
# resetting the norm because it is 0.9999999869781706
# resetting the norm because it is 1.0001329532767071
# resetting the norm because it is 0.9999999979325092
# resetting the norm because it is 0.9999964654709308
# resetting the norm because it is 0.9999868243781523
# resetting the norm because it is 0.9999850430753536
# resetting the norm because it is 0.9999999868421454
# resetting the norm because it is 1.0001368705846216
# resetting the norm because it is 1.0000000018343989
# resetting the norm because it is 0.9999961999010428
# resetting the norm because it is 0.9999858681244693
# resetting the norm because it is 0.9999839940765732
# resetting the norm because it is 0.9999999866935747
# resetting the norm because it is 1.0001397318478995
# resetting the norm because it is 1.000000005668845
# resetting the norm because it is 0.9999959856200636
# resetting the norm because it is 0.9999851046994597
# resetting the norm because it is 0.9999831651601441
# resetting the norm because it is 0.999999986535338
# resetting the norm because it is 1.0001422419085417
# resetting the norm because it is 1.0000000096361354
# resetting the norm because it is 0.9999957850192251
# resetting the norm because it is 0.9999843944717114
# resetting the norm because it is 0.9999823987387717
# resetting the norm because it is 0.999999986368271
# resetting the norm because it is 1.000144721854634
# resetting the norm because it is 1.00000001386615
# resetting the norm because it is 0.9999955794613359
# resetting the norm because it is 0.9999836685996722
# resetting the norm because it is 0.9999816174790406
# resetting the norm because it is 0.9999999861921623
# resetting the norm because it is 1.0001472186245672
# resetting the norm because it is 1.0000000183936468
# resetting the norm because it is 0.999995365874982
# resetting the norm because it is 0.9999829158920746
# resetting the norm because it is 0.9999808089676109
# resetting the norm because it is 0.9999999860066289
# resetting the norm because it is 1.0001495972920011
# resetting the norm because it is 1.0000000231513788
# resetting the norm because it is 0.999995152958915
# resetting the norm because it is 0.9999821684028632
# resetting the norm because it is 0.9999800091338626
# resetting the norm because it is 0.9999999858118067
# resetting the norm because it is 1.0001515882987717
# resetting the norm because it is 1.0000000279557877
# resetting the norm because it is 0.9999949594882366
# resetting the norm because it is 0.9999814948727086
# resetting the norm because it is 0.9999792945720539
# resetting the norm because it is 0.9999999856089637
# resetting the norm because it is 1.0001528727682694
# resetting the norm because it is 1.0000000325336915
# resetting the norm because it is 0.9999948092240113
# resetting the norm because it is 0.9999809818246628
# resetting the norm because it is 0.9999787611998121
# resetting the norm because it is 0.9999999854008056
# resetting the norm because it is 1.0001531003398216
# resetting the norm because it is 1.0000000365283654
# resetting the norm because it is 0.9999947292696909
# resetting the norm because it is 0.9999807274348724
# resetting the norm because it is 0.9999785173108598
# resetting the norm because it is 0.9999999851916376
# resetting the norm because it is 1.0001517752783182
# resetting the norm because it is 1.000000039417002
# resetting the norm because it is 0.9999947568147297
# resetting the norm because it is 0.9999808660461582
# resetting the norm because it is 0.9999787107009701
# resetting the norm because it is 0.9999999849878276
# resetting the norm because it is 1.0001485793289693
# resetting the norm because it is 1.0000000407766534
# resetting the norm because it is 0.999994914214572
# resetting the norm because it is 0.9999814771803219
# resetting the norm because it is 0.9999794275456111
# resetting the norm because it is 0.9999999847966582
# resetting the norm because it is 1.0001431308406707
# resetting the norm because it is 1.000000040154991
# resetting the norm because it is 0.999995222603959
# resetting the norm because it is 0.9999826354555742
# resetting the norm because it is 0.9999807480913286
# resetting the norm because it is 0.9999999846258545
# resetting the norm because it is 1.0001356578965144
# resetting the norm because it is 1.0000000376650875
# resetting the norm because it is 0.9999956545340062
# resetting the norm because it is 0.9999842386219031
# resetting the norm because it is 0.999982556565493
# resetting the norm because it is 0.9999999844805714
# resetting the norm because it is 1.000125263977201
# resetting the norm because it is 1.0000000326406437
# resetting the norm because it is 0.9999962460722865
# resetting the norm because it is 0.9999864153407871
# resetting the norm because it is 0.9999849927382098
# resetting the norm because it is 0.9999999843663651
# resetting the norm because it is 1.0001108533773928
# resetting the norm because it is 1.0000000245438885
# resetting the norm because it is 0.9999970175008298
# resetting the norm because it is 0.9999892362726402
# resetting the norm because it is 0.9999881315126814
# resetting the norm because it is 0.9999999842874026
# resetting the norm because it is 1.0001031930659667
# resetting the norm because it is 1.000000021348376
# resetting the norm because it is 0.9999973776807113
# resetting the norm because it is 0.9999905603378721
# resetting the norm because it is 0.9999896119201193
# resetting the norm because it is 0.9999999842237995
# resetting the norm because it is 1.0001165711870326
# resetting the norm because it is 1.0000000339365671
# resetting the norm because it is 0.9999966206418146
# resetting the norm because it is 0.9999878455477237
# resetting the norm because it is 0.9999866468350483
# resetting the norm because it is 0.9999999841319238
# resetting the norm because it is 1.000127445262423
# resetting the norm because it is 1.000000046497236
# resetting the norm because it is 0.9999959184770707
# resetting the norm because it is 0.9999853380823011
# resetting the norm because it is 0.9999839192525534
# resetting the norm because it is 0.9999999840116788
# resetting the norm because it is 1.0001359375849166
# resetting the norm because it is 1.0000000584299222
# resetting the norm because it is 0.9999953053140785
# resetting the norm because it is 0.9999831598596102
# resetting the norm because it is 0.9999815618759473
# resetting the norm because it is 0.9999999838656024
# resetting the norm because it is 1.0001404595950014
# resetting the norm because it is 1.000000067302807
# resetting the norm because it is 0.9999949273694978
# resetting the norm because it is 0.9999818350674402
# resetting the norm because it is 0.999980147113628
# resetting the norm because it is 0.9999999837043962
# resetting the norm because it is 1.0001432390211658
# resetting the norm because it is 1.0000000748182192
# resetting the norm because it is 0.9999946582837818
# resetting the norm because it is 0.99998090589545
# resetting the norm because it is 0.9999791700057405
# resetting the norm because it is 0.9999999835334216
# resetting the norm because it is 1.0001524162315847
# resetting the norm because it is 1.000000090977296
# resetting the norm because it is 0.9999938894446069
# resetting the norm because it is 0.9999781885715409
# resetting the norm because it is 0.9999762440417599
# resetting the norm because it is 0.9999999833272258
# resetting the norm because it is 1.0001565577788196
# resetting the norm because it is 1.000000101892744
# resetting the norm because it is 0.9999934744354669
# resetting the norm because it is 0.9999767476399913
# resetting the norm because it is 0.9999747201363033
# resetting the norm because it is 0.9999999831037287
# resetting the norm because it is 1.000151234962175
# resetting the norm because it is 1.0000000999794199
# resetting the norm because it is 0.9999938124489715
# resetting the norm because it is 0.9999780035508629
# resetting the norm because it is 0.999976138027162
# resetting the norm because it is 0.9999999829025567
# resetting the norm because it is 1.000140666592946
# resetting the norm because it is 1.0000000904512234
# resetting the norm because it is 0.9999945433862542
# resetting the norm because it is 0.9999806562899808
# resetting the norm because it is 0.9999790685289672
# resetting the norm because it is 0.9999999827410855
# resetting the norm because it is 1.0001312116883017
# resetting the norm because it is 1.0000000821706234
# resetting the norm because it is 0.9999951577868718
# resetting the norm because it is 0.9999828832156036
# resetting the norm because it is 0.9999815255317321
# resetting the norm because it is 0.999999982610363
# resetting the norm because it is 1.000125359150344
# resetting the norm because it is 1.000000078448643
# resetting the norm because it is 0.9999954989373836
# resetting the norm because it is 0.9999841300551852
# resetting the norm because it is 0.9999829119310952
# resetting the norm because it is 0.9999999824965906
# resetting the norm because it is 1.0001217699390859
# resetting the norm because it is 1.000000077524391
# resetting the norm because it is 0.9999956802576959
# resetting the norm because it is 0.9999848050147657
# resetting the norm because it is 0.9999836751393062
# resetting the norm because it is 0.9999999823924858
# resetting the norm because it is 1.000119883988332
# resetting the norm because it is 1.0000000787694798
# resetting the norm because it is 0.9999957462520098
# resetting the norm because it is 0.9999850689945456
# resetting the norm because it is 0.9999839922743292
# resetting the norm because it is 0.9999999822932824
# resetting the norm because it is 1.0001197111832016
# resetting the norm because it is 1.0000000823848239
# resetting the norm because it is 0.9999956970402223
# resetting the norm because it is 0.999984924709455
# resetting the norm because it is 0.9999838687334245
# resetting the norm because it is 0.9999999821946174
# resetting the norm because it is 1.0001202237284175
# resetting the norm because it is 1.0000000870955548
# resetting the norm because it is 0.9999955998112593
# resetting the norm because it is 0.999984611465791
# resetting the norm because it is 0.9999835641155311
# resetting the norm because it is 0.999999982094784
# resetting the norm because it is 1.0001210120447401
# resetting the norm because it is 1.0000000923905976
# resetting the norm because it is 0.9999954809310698
# resetting the norm because it is 0.9999842230540106
# resetting the norm because it is 0.9999831800377932
# resetting the norm because it is 0.9999999819930814
# resetting the norm because it is 1.0001214717854396
# resetting the norm because it is 1.0000000973507541
# resetting the norm because it is 0.9999953822664819
# resetting the norm because it is 0.999983907185326
# resetting the norm because it is 0.9999828752313561
# resetting the norm because it is 0.9999999818903393
# resetting the norm because it is 1.0001205482897768
# resetting the norm because it is 1.0000001001598364
# resetting the norm because it is 0.9999953803827345
# resetting the norm because it is 0.9999839324677675
# resetting the norm because it is 0.9999829366974987
# resetting the norm because it is 0.9999999817900835
# resetting the norm because it is 1.0001163015632706
# resetting the norm because it is 1.0000000973396026
# resetting the norm because it is 0.9999956135971106
# resetting the norm because it is 0.9999847819734168
# resetting the norm because it is 0.9999838782142492
# resetting the norm because it is 0.9999999817002773
# resetting the norm because it is 1.0001055349630752
# resetting the norm because it is 1.0000000835172216
# resetting the norm because it is 0.9999962785688145
# resetting the norm because it is 0.999987137928514
# resetting the norm because it is 0.9999864203114414
# resetting the norm because it is 0.999999981633458
# resetting the norm because it is 1.0001133661034742
# resetting the norm because it is 1.0000001004283237
# resetting the norm because it is 0.9999956925866539
# resetting the norm because it is 0.9999851159770283
# resetting the norm because it is 0.9999842965879252
# resetting the norm because it is 0.9999999815506003
# resetting the norm because it is 1.0001245387451878
# resetting the norm because it is 1.0000001254732251
# resetting the norm because it is 0.9999948037283047
# resetting the norm because it is 0.9999820422499474
# resetting the norm because it is 0.9999810607609633
# resetting the norm because it is 0.9999999814406314
# resetting the norm because it is 1.0001340078376602
# resetting the norm because it is 1.0000001499786215
# resetting the norm because it is 0.9999939642006901
# resetting the norm because it is 0.9999791491741402
# resetting the norm because it is 0.9999780261077537
# resetting the norm because it is 0.9999999813035546
# resetting the norm because it is 1.000142633412603
# resetting the norm because it is 1.0000001751730836
# resetting the norm because it is 0.9999931271516725
# resetting the norm because it is 0.999976273618162
# resetting the norm because it is 0.9999750196866554
# resetting the norm because it is 0.9999999811382435
# resetting the norm because it is 1.000150611187325
# resetting the norm because it is 1.0000002012579843
# resetting the norm because it is 0.9999922866901035
# resetting the norm because it is 0.9999733955809486
# resetting the norm because it is 0.9999720208573943
# resetting the norm because it is 0.9999999809436405
# resetting the norm because it is 1.000157299053786
# resetting the norm because it is 1.0000002263885468
# resetting the norm because it is 0.9999915150260111
# resetting the norm because it is 0.9999707668519935
# resetting the norm because it is 0.9999692969851323
# resetting the norm because it is 0.9999999807220732
# resetting the norm because it is 1.0001604907555286
# resetting the norm because it is 1.000000244038375
# resetting the norm because it is 0.9999910553176254
# resetting the norm because it is 0.9999692317496686
# resetting the norm because it is 0.9999677407296224
# resetting the norm because it is 0.9999999804871063
# resetting the norm because it is 1.0001576426677332
# resetting the norm because it is 1.000000245783783
# resetting the norm because it is 0.9999911995245523
# resetting the norm because it is 0.999969797437083
# resetting the norm because it is 0.9999684096559838
# resetting the norm because it is 0.9999999802651313
# resetting the norm because it is 1.0001555249560812
# resetting the norm because it is 1.000000249373766
# resetting the norm because it is 0.9999912701193622
# resetting the norm because it is 0.9999701058628112
# resetting the norm because it is 0.9999688047896186
# resetting the norm because it is 0.9999999800526487
# resetting the norm because it is 1.000159307536525
# resetting the norm because it is 1.0000002702206203
# resetting the norm because it is 0.9999907306380084
# resetting the norm because it is 0.9999683051337892
# resetting the norm because it is 0.9999669802379194
# resetting the norm because it is 0.9999999798246753
# resetting the norm because it is 1.0001638956232735
# resetting the norm because it is 1.000000294927061
# resetting the norm because it is 0.9999900790470503
# resetting the norm because it is 0.9999661246644125
# resetting the norm because it is 0.9999647646689137
# resetting the norm because it is 0.9999999795768401
# resetting the norm because it is 1.0001634979929905
# resetting the norm because it is 1.0000003050110164
# resetting the norm because it is 0.9999899522889021
# resetting the norm because it is 0.9999657611421405
# resetting the norm because it is 0.9999644639782632
# resetting the norm because it is 0.9999999793315751
# resetting the norm because it is 1.000154507347254
# resetting the norm because it is 1.000000287108107
# resetting the norm because it is 0.999990760146705
# resetting the norm because it is 0.9999686114204026
# resetting the norm because it is 0.999967526308907
# resetting the norm because it is 0.9999999791257713
# resetting the norm because it is 1.0001463378886029
# resetting the norm because it is 1.0000002710956486
# resetting the norm because it is 0.999991464041636
# resetting the norm because it is 0.999971090438026
# resetting the norm because it is 0.9999701848922173
# resetting the norm because it is 0.9999999789519229
# resetting the norm because it is 1.000139098418825
# resetting the norm because it is 1.0000002573798896
# resetting the norm because it is 0.9999920597423774
# resetting the norm because it is 0.999973186737663
# resetting the norm because it is 0.9999724311768584
# resetting the norm because it is 0.9999999788034742
# resetting the norm because it is 1.0001326267544313
# resetting the norm because it is 1.0000002454996575
# resetting the norm because it is 0.9999925698809575
# resetting the norm because it is 0.9999749805592317
# resetting the norm because it is 0.9999743518102121
# resetting the norm because it is 0.9999999786755315
# resetting the norm because it is 1.0001265302546742
# resetting the norm because it is 1.0000002342472043
# resetting the norm because it is 0.9999930369643794
# resetting the norm because it is 0.9999766188443441
# resetting the norm because it is 0.9999761014119916
# resetting the norm because it is 0.9999999785650792
# resetting the norm because it is 1.0001201693817847
# resetting the norm because it is 1.0000002216019144
# resetting the norm because it is 0.999993523002952
# resetting the norm because it is 0.99997831311533
# resetting the norm because it is 0.9999778994209279
# resetting the norm because it is 0.9999999784710417
# resetting the norm because it is 1.0001123563824295
# resetting the norm because it is 1.0000002038060254
# resetting the norm because it is 0.9999941332821806
# resetting the norm because it is 0.9999804189307369
# resetting the norm because it is 0.9999801106995441
# resetting the norm because it is 0.9999999783947124
# resetting the norm because it is 1.0001067715984573
# resetting the norm because it is 1.0000001926286999
# resetting the norm because it is 0.9999945324231356
# resetting the norm because it is 0.9999818015382602
# resetting the norm because it is 0.9999815683919014
# resetting the norm because it is 0.999999978329621
# resetting the norm because it is 1.0001137652658607
# resetting the norm because it is 1.0000002222499456
# resetting the norm because it is 0.9999937969833448
# resetting the norm because it is 0.9999793558944687
# resetting the norm because it is 0.9999791014708574
# resetting the norm because it is 0.9999999782509823
# resetting the norm because it is 1.0001171216275926
# resetting the norm because it is 1.0000002414710494
# resetting the norm because it is 0.9999933635795791
# resetting the norm because it is 0.9999779345870422
# resetting the norm because it is 0.9999776905336268
# resetting the norm because it is 0.9999999781654334
# resetting the norm because it is 1.0001191687678481
# resetting the norm because it is 1.0000002570717186
# resetting the norm because it is 0.9999930399872762
# resetting the norm because it is 0.9999768874621201
# resetting the norm because it is 0.9999766673131293
# resetting the norm because it is 0.9999999780756567
# resetting the norm because it is 1.0001214531318527
# resetting the norm because it is 1.0000002744251235
# resetting the norm because it is 0.9999926785628525
# resetting the norm because it is 0.9999757170497763
# resetting the norm because it is 0.999975522614199
# resetting the norm because it is 0.9999999779809817
# resetting the norm because it is 1.0001254229616392
# resetting the norm because it is 1.0000002995308852
# resetting the norm because it is 0.9999921218471858
# resetting the norm because it is 0.999973895839126
# resetting the norm because it is 0.9999737199145198
# resetting the norm because it is 0.9999999778770626
# resetting the norm because it is 1.000131057439216
# resetting the norm because it is 1.0000003334366785
# resetting the norm because it is 0.9999913489419867
# resetting the norm because it is 0.9999713566682975
# resetting the norm because it is 0.9999711941369721
# resetting the norm because it is 0.9999999777588364
# resetting the norm because it is 1.0001390855131036
# resetting the norm because it is 1.0000003808673725
# resetting the norm because it is 0.9999902432520704
# resetting the norm because it is 0.9999677121665591
# resetting the norm because it is 0.999967554969711
# resetting the norm because it is 0.9999999776178203
# resetting the norm because it is 1.0001494126480717
# resetting the norm because it is 1.0000004438573875
# resetting the norm because it is 0.9999887616005528
# resetting the norm because it is 0.9999628222048207
# resetting the norm because it is 0.9999626650143849
# resetting the norm because it is 0.9999999774432539
# resetting the norm because it is 1.000161034645411
# resetting the norm because it is 1.000000520080341
# resetting the norm because it is 0.9999869759350907
# resetting the norm because it is 0.9999569326257792
# resetting the norm because it is 0.9999567797591522
# resetting the norm because it is 0.9999999772249826
# resetting the norm because it is 1.0001704706578487
# resetting the norm because it is 1.0000005919238866
# resetting the norm because it is 0.9999853522337573
# resetting the norm because it is 0.9999516059177338
# resetting the norm because it is 0.9999514899255901
# resetting the norm because it is 0.9999999769667398
# resetting the norm because it is 1.0001735430623608
# resetting the norm because it is 1.0000006324716602
# resetting the norm because it is 0.9999845746811881
# resetting the norm because it is 0.9999491240636335
# resetting the norm because it is 0.9999491049000442
# resetting the norm because it is 0.99999997669587
# resetting the norm because it is 1.0001710313991354
# resetting the norm because it is 1.0000006413389146
# resetting the norm because it is 0.999984615439066
# resetting the norm because it is 0.9999493775500196
# resetting the norm because it is 0.9999494948524702
# resetting the norm because it is 0.9999999764388592
# ...
# resetting the norm because it is 0.9999999761118215
# resetting the norm because it is 0.9999999761118081
# resetting the norm because it is 0.9999999761118141
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118512
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.9999999761118245
# resetting the norm because it is 0.9999999761118156
# resetting the norm because it is 0.9999999761118185
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118561
# resetting the norm because it is 0.9999999761118301
# resetting the norm because it is 0.9999999761118228
# resetting the norm because it is 0.9999999761118119
# resetting the norm because it is 0.9999999761118169
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118472
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.9999999761118253
# resetting the norm because it is 0.999999976111818
# resetting the norm because it is 0.9999999761118205
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118512
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.9999999761118241
# resetting the norm because it is 0.9999999761118151
# resetting the norm because it is 0.9999999761118192
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118439
# resetting the norm because it is 0.9999999761118297
# resetting the norm because it is 0.9999999761118261
# resetting the norm because it is 0.9999999761118201
# resetting the norm because it is 0.9999999761118221
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118472
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.999999976111825
# resetting the norm because it is 0.9999999761118179
# resetting the norm because it is 0.9999999761118211
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118413
# resetting the norm because it is 0.9999999761118297
# resetting the norm because it is 0.9999999761118267
# resetting the norm because it is 0.9999999761118219
# resetting the norm because it is 0.9999999761118235
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.999999976111844
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.9999999761118259
# resetting the norm because it is 0.9999999761118199
# resetting the norm because it is 0.9999999761118227
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118392
# resetting the norm because it is 0.9999999761118297
# resetting the norm because it is 0.9999999761118272
# resetting the norm because it is 0.9999999761118233
# resetting the norm because it is 0.9999999761118246
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118413
# resetting the norm because it is 0.9999999761118298
# resetting the norm because it is 0.9999999761118264
# resetting the norm because it is 0.9999999761118218
# resetting the norm because it is 0.9999999761118239
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118373
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118277
# resetting the norm because it is 0.9999999761118243
# resetting the norm because it is 0.9999999761118253
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118392
# resetting the norm because it is 0.9999999761118297
# resetting the norm because it is 0.9999999761118271
# resetting the norm because it is 0.9999999761118231
# resetting the norm because it is 0.9999999761118249
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.999999976111836
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.999999976111828
# resetting the norm because it is 0.9999999761118253
# resetting the norm because it is 0.9999999761118262
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118374
# resetting the norm because it is 0.9999999761118298
# resetting the norm because it is 0.9999999761118276
# resetting the norm because it is 0.9999999761118242
# resetting the norm because it is 0.9999999761118258
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118348
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118283
# resetting the norm because it is 0.9999999761118261
# resetting the norm because it is 0.9999999761118269
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118359
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118279
# resetting the norm because it is 0.9999999761118252
# resetting the norm because it is 0.9999999761118264
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118338
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118284
# resetting the norm because it is 0.9999999761118267
# resetting the norm because it is 0.9999999761118273
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118348
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118281
# resetting the norm because it is 0.9999999761118259
# resetting the norm because it is 0.9999999761118269
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.999999976111833
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118287
# resetting the norm because it is 0.9999999761118271
# resetting the norm because it is 0.9999999761118276
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118338
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118283
# resetting the norm because it is 0.9999999761118266
# resetting the norm because it is 0.9999999761118274
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118322
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118274
# resetting the norm because it is 0.9999999761118279
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118329
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118286
# resetting the norm because it is 0.9999999761118271
# resetting the norm because it is 0.9999999761118278
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118319
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118279
# resetting the norm because it is 0.9999999761118283
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118323
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118276
# resetting the norm because it is 0.999999976111828
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118313
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118282
# resetting the norm because it is 0.9999999761118284
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118318
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118278
# resetting the norm because it is 0.9999999761118283
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.999999976111831
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118284
# resetting the norm because it is 0.9999999761118286
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118313
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118282
# resetting the norm because it is 0.9999999761118286
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118307
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118286
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.999999976111831
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118283
# resetting the norm because it is 0.9999999761118287
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118304
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118307
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118287
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118302
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118304
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118287
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118301
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118302
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118299
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.99999997611183
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118288
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118298
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118298
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118297
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118298
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118289
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118296
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118294
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118292
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.9999999761118293
# resetting the norm because it is 0.9999999761118291
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.999999976111829
# resetting the norm because it is 0.9999999761118291
# Integration failed with status -1: Required step size is less than spacing between numbers.
# Final time: 99.99000000000001
# Quaternion constraint satisfied throughout the simulation.
